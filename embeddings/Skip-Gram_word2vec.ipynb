# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:08, 3.60MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words) # note that decrease threshold will also decrease the number of train_words chosen
# Out:
# 4626109

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    rand = int(random.random()*window_size + 1)
    # don't forget to get rid of duplicates and the word itself
    return np.unique(words[max(0,idx - rand): idx] + words[idx+1:idx + rand ] )# we don't need min for upper bound

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape = [None], name = "inputs")
    labels = tf.placeholder(tf.int32, shape = [None, None], name = "labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape = [n_vocab, n_embedding], minval = -1, maxval = 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # softmax_w = tf.Variable(tf.random_uniform(shape = [n_embedding, n_vocab], minval = -1, maxval = 1), name = "weights") # create softmax weight matrix here
    # softmax_b = tf.Variable(tf.random_uniform(shape = [n_vocab], minval = -1, maxval = 1), name = "biases")# create softmax biases here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6713 0.1355 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6112 0.0429 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5332 0.0429 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5789 0.0429 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4936 0.0428 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5438 0.0428 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5653 0.0428 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5239 0.0428 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4790 0.0429 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4179 0.0428 sec/batch
# Nearest to be: michel, nitrides, would, palmeiro, covertly, psalms, petronius, saif,
# Nearest to from: gardena, loneliness, topsy, piercers, chicxulub, cree, mogadishu, hungarian,
# Nearest to people: directors, parque, west, ballantine, clips, identifies, contradict, dramatic,
# Nearest to that: international, horoscope, rebbe, inquire, larps, middleware, desegregate, stripe,
# Nearest to an: immanuel, juggling, enslavable, hamsun, bayes, decades, laver, logically,
# Nearest to war: gonna, mightiest, chrysler, carillon, adding, litigant, mcbeal, hazards,
# Nearest to they: comprehensive, foulke, golfo, latinos, pecan, fraggle, keen, maltin,
# Nearest to with: soninke, newcomers, teach, heron, jia, ineffectiveness, ede, validate,
# Nearest to notes: rommel, stig, myth, naa, hurley, goldman, sociological, maxims,
# Nearest to operations: alen, perthshire, finish, awd, researcher, weightlessness, servicio, rd,
# Nearest to recorded: roosevelts, newsome, messalina, mundane, hirohito, scalia, kurdish, unfair,
# Nearest to additional: cavities, herrn, sympathizers, freezes, cdm, lots, pata, blades,
# Nearest to know: woese, harar, fuca, embry, anhydrous, igor, superconductor, propylaea,
# Nearest to orthodox: gears, humphry, ussher, underworld, audited, punches, semiconductors, phase,
# Nearest to applications: lingua, dryness, levies, roommate, sugary, unenforceable, trie, intermixed,
# Nearest to file: smoking, peddle, lerner, iota, ht, transient, doha, compatibility,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4839 0.0439 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3583 0.0428 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3553 0.0426 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2568 0.0428 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2427 0.0427 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1756 0.0428 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1257 0.0427 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1131 0.0427 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9863 0.0428 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9909 0.0427 sec/batch
# Nearest to be: would, awarded, michel, chief, depth, inter, deceive, psalms,
# Nearest to from: winter, built, loneliness, native, chicxulub, gardena, level, personal,
# Nearest to people: west, ballantine, directors, identifies, parque, i, dramatic, complementary,
# Nearest to that: not, international, inquire, well, stripe, compensation, radicals, manche,
# Nearest to an: immanuel, decades, juggling, internally, variously, enslavable, comes, variants,
# Nearest to war: gonna, chrysler, adding, mightiest, hazards, dealing, charges, december,
# Nearest to they: comprehensive, foulke, world, keen, tracking, associated, reduces, libyans,
# Nearest to with: newcomers, teach, soninke, colonization, heron, ineffectiveness, jia, patrolling,
# Nearest to notes: myth, maxims, stig, rommel, naa, goldman, explosively, hartley,
# Nearest to operations: rd, finish, alen, awd, licences, weightlessness, remembering, nine,
# Nearest to recorded: mundane, unfair, along, enough, roosevelts, newsome, hirohito, lim,
# Nearest to additional: cdm, cavities, lots, freezes, mapsto, riding, morgan, swelled,
# Nearest to know: regarding, fuca, cd, widely, parallels, igor, ornithology, shipments,
# Nearest to orthodox: gears, humphry, phase, underworld, spelling, designers, ussher, audited,
# Nearest to applications: lingua, levies, unprecedented, reformed, severely, assemblers, printing, bearers,
# Nearest to file: smoking, determine, peddle, lerner, compatibility, transient, protection, ht,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9614 0.0438 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9300 0.0428 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9013 0.0427 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8752 0.0428 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8026 0.0426 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8199 0.0429 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7954 0.0428 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7757 0.0427 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7897 0.0429 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7744 0.0429 sec/batch
# Nearest to be: would, awarded, michel, covertly, inter, exact, researchers, barriers,
# Nearest to from: loneliness, winter, hungarian, chicxulub, cree, built, replaces, gardena,
# Nearest to people: west, directors, ballantine, parque, identifies, clips, dramatic, complementary,
# Nearest to that: not, inquire, stripe, horoscope, appendant, renegade, international, notoriety,
# Nearest to an: immanuel, juggling, decades, enslavable, internally, logically, variously, aerial,
# Nearest to war: gonna, mightiest, chrysler, dealing, adding, hazards, ok, bailiwicks,
# Nearest to they: comprehensive, foulke, keen, tracking, tale, reduces, world, armored,
# Nearest to with: teach, newcomers, soninke, indisputable, ineffectiveness, impressive, colonization, patrolling,
# Nearest to notes: myth, maxims, goldman, jonathan, transcendent, request, ballantine, explosively,
# Nearest to operations: rd, finish, alen, remembering, licences, researcher, weightlessness, dmitri,
# Nearest to recorded: unfair, roosevelts, hirohito, mundane, koch, along, newsome, convey,
# Nearest to additional: cavities, lots, cdm, freezes, mapsto, determined, portrayal, recombinant,
# Nearest to know: regarding, parallels, igor, fuca, cd, shipments, ideologically, hindus,
# Nearest to orthodox: phase, gears, humphry, spelling, underworld, referenda, bare, adm,
# Nearest to applications: lingua, reformed, severely, levies, dryness, mainly, assemblers, randall,
# Nearest to file: smoking, determine, ht, compatibility, protection, transient, racist, lerner,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7894 0.0440 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7705 0.0431 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7422 0.0431 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7287 0.0429 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7617 0.0429 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6889 0.0431 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7027 0.0431 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7212 0.0430 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6878 0.0428 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6760 0.0429 sec/batch
# Nearest to be: would, uncommonly, discogs, awarded, barriers, spectra, covertly, maji,
# Nearest to from: loneliness, winter, chicxulub, vending, personal, gardena, cree, replaces,
# Nearest to people: west, directors, parque, ballantine, clips, identifies, rejected, dramatic,
# Nearest to that: not, middleware, inquire, stripe, renegade, appendant, horoscope, rebbe,
# Nearest to an: immanuel, juggling, enslavable, decades, internally, logically, aerial, variously,
# Nearest to war: gonna, mightiest, chrysler, bailiwicks, december, dealing, ok, sociopathic,
# Nearest to they: comprehensive, foulke, tale, keen, stranded, reduces, latinos, fraggle,
# Nearest to with: teach, ede, newcomers, colonization, soninke, pressing, ineffectiveness, impressive,
# Nearest to notes: myth, maxims, jonathan, goldman, negotiator, stig, ballantine, naa,
# Nearest to operations: rd, alen, finish, jin, basketball, dmitri, awd, researcher,
# Nearest to recorded: roosevelts, koch, conspired, hirohito, kurdish, unfair, mundane, newsome,
# Nearest to additional: cavities, cdm, lots, freezes, blades, recombinant, mapsto, determined,
# Nearest to know: regarding, parallels, fuca, igor, harar, patrician, paralysis, shipments,
# Nearest to orthodox: humphry, ussher, gears, phase, spelling, adm, punches, underworld,
# Nearest to applications: lingua, intermixed, dryness, bot, assemblers, roommate, levies, sugary,
# Nearest to file: smoking, determine, transient, compatibility, ht, lerner, protection, peddle,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6942 0.0438 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6683 0.0427 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6274 0.0428 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6519 0.0427 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6344 0.0428 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6409 0.0426 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6011 0.0323 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5731 0.0429 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5124 0.0429 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5174 0.0430 sec/batch
# Nearest to be: would, discogs, purpose, exact, barriers, spectra, nitrides, maji,
# Nearest to from: winter, loneliness, bait, chicxulub, vending, gardena, cree, accounts,
# Nearest to people: parque, west, ballantine, directors, identifies, clips, lehman, i,
# Nearest to that: not, middleware, appendant, renegade, stripe, horoscope, inquire, rebbe,
# Nearest to an: immanuel, juggling, logically, enslavable, internally, nan, variants, decades,
# Nearest to war: gonna, mightiest, chrysler, ok, december, bailiwicks, jts, legislate,
# Nearest to they: comprehensive, foulke, rather, stranded, keen, pecan, reduces, tale,
# Nearest to with: soninke, ede, teach, indisputable, newcomers, pressing, rodham, colonization,
# Nearest to notes: myth, stig, maxims, goldman, jonathan, pillow, negotiator, explosively,
# Nearest to operations: awd, jin, alen, servicio, remembering, fz, rd, researcher,
# Nearest to recorded: roosevelts, koch, conspired, hirohito, kurdish, rumor, newsome, messalina,
# Nearest to additional: cavities, blades, cdm, mapsto, pata, fabrics, lots, determined,
# Nearest to know: regarding, parallels, woese, patrician, harar, paralysis, fuca, cd,
# Nearest to orthodox: humphry, ussher, adm, phase, spelling, punches, gears, abbr,
# Nearest to applications: dryness, intermixed, lingua, assemblers, bot, sac, logic, delete,
# Nearest to file: compatibility, determine, ht, smoking, peddle, compression, transient, adapter,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4887 0.0438 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4822 0.0429 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4547 0.0427 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5259 0.0427 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5003 0.0428 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4744 0.0431 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4318 0.0432 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4132 0.0426 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4391 0.0431 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4180 0.0429 sec/batch
# Nearest to be: would, spectra, purpose, exact, nitrides, maji, researchers, barriers,
# Nearest to from: loneliness, chicxulub, winter, gardena, accounts, bait, ancestral, mogadishu,
# Nearest to people: parque, identifies, ballantine, directors, west, lehman, clips, i,
# Nearest to that: not, middleware, if, appendant, intermediary, inquire, apion, will,
# Nearest to an: internally, immanuel, logically, enslavable, juggling, variously, aerial, variants,
# Nearest to war: mightiest, gonna, legislate, chrysler, ok, bailiwicks, carillon, sociopathic,
# Nearest to they: comprehensive, rather, stranded, reduces, inaugurate, keen, foulke, pecan,
# Nearest to with: ede, soninke, indisputable, rodham, teach, pressing, tireless, ceases,
# Nearest to notes: myth, maxims, pillow, stig, jonathan, negotiator, goldman, hurley,
# Nearest to operations: awd, operation, jin, servicio, minimized, alen, remembering, fz,
# Nearest to recorded: roosevelts, rumor, hirohito, conspired, messalina, bread, newsome, koch,
# Nearest to additional: cavities, cdm, blades, mapsto, pata, determined, fabrics, lots,
# Nearest to know: regarding, parallels, woese, paralysis, knows, harar, cd, patrician,
# Nearest to orthodox: ussher, humphry, adm, punches, phase, spelling, holy, neo,
# Nearest to applications: dryness, intermixed, using, delete, assemblers, generic, lingua, converting,
# Nearest to file: compatibility, determine, ht, smoking, compression, adapter, data, files,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4368 0.0438 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4277 0.0429 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4489 0.0427 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4046 0.0427 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4038 0.0428 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4528 0.0429 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3994 0.0427 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3711 0.0429 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3976 0.0430 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3744 0.0430 sec/batch
# Nearest to be: would, spectra, mistake, uncommonly, accumulation, purpose, qed, exact,
# Nearest to from: gardena, winter, chicxulub, loneliness, piercers, mogadishu, ancestral, accounts,
# Nearest to people: parque, identifies, lehman, west, ballantine, i, clips, directors,
# Nearest to that: not, middleware, if, uninhibited, appendant, inquire, apion, will,
# Nearest to an: internally, immanuel, logically, thereby, cosmologies, juggling, nan, variants,
# Nearest to war: gonna, mightiest, legislate, chrysler, delegates, december, carillon, deliberations,
# Nearest to they: stranded, rather, foulke, comprehensive, keen, inaugurate, pecan, reduces,
# Nearest to with: ede, soninke, rodham, offside, teach, tireless, newcomers, synthetically,
# Nearest to notes: myth, maxims, jonathan, stig, negotiator, pillow, goldman, rommel,
# Nearest to operations: operation, awd, minimized, compete, servicio, jin, differentiable, fz,
# Nearest to recorded: roosevelts, rumor, conspired, bread, newsome, messalina, conversation, hirohito,
# Nearest to additional: cavities, cdm, pata, mapsto, lots, blades, fabrics, determined,
# Nearest to know: regarding, woese, parallels, knows, harar, hebrew, patrician, cd,
# Nearest to orthodox: churches, holy, ussher, antioch, adm, spelling, christian, neo,
# Nearest to applications: intermixed, assemblers, generic, dryness, delete, sugary, convenient, logic,
# Nearest to file: compatibility, files, ht, directory, determine, smoking, adapter, compression,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3633 0.0436 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3816 0.0430 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3878 0.0428 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3624 0.0429 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3686 0.0428 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3738 0.0430 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3717 0.0429 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3762 0.0429 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3310 0.0428 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3634 0.0428 sec/batch
# Nearest to be: would, spectra, qed, mistake, uncommonly, nitrides, snark, maji,
# Nearest to from: gardena, mogadishu, chicxulub, winter, accounts, ancestral, loneliness, vending,
# Nearest to people: parque, identifies, west, lehman, ballantine, clips, pitting, contradict,
# Nearest to that: not, middleware, inquire, uninhibited, rebbe, achaemenids, appendant, renegade,
# Nearest to an: internally, cosmologies, logically, immanuel, folksong, nan, aerial, equivalent,
# Nearest to war: mightiest, gonna, yasser, army, legislate, chrysler, pohnpei, leader,
# Nearest to they: rather, foulke, stranded, keen, maltin, saved, comprehensive, antiretroviral,
# Nearest to with: ede, tireless, soninke, rodham, newcomers, pressing, ineffectiveness, offside,
# Nearest to notes: stig, maxims, jonathan, myth, goldman, hurley, negotiator, pillow,
# Nearest to operations: operation, awd, advanced, jin, fz, compete, minimized, botswana,
# Nearest to recorded: roosevelts, rumor, conversation, conspired, bread, newsome, messalina, hirohito,
# Nearest to additional: cavities, pata, cdm, lots, fabrics, blades, recombinant, radiocommunication,
# Nearest to know: regarding, parallels, woese, knows, harar, signification, hebrew, spatial,
# Nearest to orthodox: churches, holy, ussher, adm, antioch, ordain, lutherans, neo,
# Nearest to applications: assemblers, sugary, dryness, delete, intermixed, intermolecular, hallowed, logic,
# Nearest to file: compatibility, directory, files, ht, data, communications, compression, packages,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3552 0.0439 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3213 0.0430 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3951 0.0428 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4196 0.0428 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3750 0.0428 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2910 0.0429 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3051 0.0426 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3666 0.0429 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2459 0.0427 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2981 0.0428 sec/batch
# Nearest to be: would, qed, mistake, spectra, nitrides, psalms, snark, lakshmi,
# Nearest to from: winter, gardena, chicxulub, mogadishu, tsushima, native, vending, topsy,
# Nearest to people: parque, identifies, west, lehman, ballantine, uncertain, clips, ensured,
# Nearest to that: not, uninhibited, appendant, middleware, if, renegade, will, responsive,
# Nearest to an: sorbs, folksong, internally, aerial, immanuel, equivalent, trapper, nan,
# Nearest to war: mightiest, gonna, schwarzenberg, army, yasser, carillon, deliberations, legislate,
# Nearest to they: rather, stranded, foulke, saved, antiretroviral, inaugurate, keen, latinos,
# Nearest to with: ede, soninke, tireless, rodham, teach, colonization, naghten, pressing,
# Nearest to notes: myth, maxims, hurley, stig, jonathan, goldman, pillow, ballantine,
# Nearest to operations: operation, awd, advanced, fz, differentiable, compete, minimized, botswana,
# Nearest to recorded: roosevelts, rumor, bread, conversation, conspired, hirohito, stern, elia,
# Nearest to additional: cavities, pata, fabrics, cdm, lots, radiocommunication, recombinant, mapsto,
# Nearest to know: regarding, parallels, knows, woese, signification, harar, embry, patrician,
# Nearest to orthodox: churches, ussher, holy, antioch, ordain, adm, lutherans, spelling,
# Nearest to applications: assemblers, printing, sugary, hallowed, dryness, delete, intermixed, microcode,
# Nearest to file: compatibility, files, directory, ht, packages, data, compression, download,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3188 0.0438 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3081 0.0428 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3255 0.0213 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2652 0.0428 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2111 0.0430 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2488 0.0430 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2086 0.0428 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2012 0.0428 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2559 0.0432 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1989 0.0434 sec/batch
# Nearest to be: would, nitrides, mistake, spectra, maji, immigrating, qed, snark,
# Nearest to from: winter, gardena, vending, ancestral, chicxulub, topsy, tsushima, accounts,
# Nearest to people: parque, identifies, lehman, uncertain, clips, ballantine, west, complementary,
# Nearest to that: not, uninhibited, appendant, renegade, compensation, apion, sacrificed, rebbe,
# Nearest to an: internally, aerial, sorbs, trapper, folksong, cosmologies, generalizations, immanuel,
# Nearest to war: mightiest, yasser, gonna, army, deliberations, carillon, pohnpei, schwarzenberg,
# Nearest to they: stranded, rather, foulke, inaugurate, keen, antiretroviral, latinos, rebranding,
# Nearest to with: ede, tireless, soninke, colonization, rodham, zug, mortuary, again,
# Nearest to notes: stig, maxims, myth, jonathan, hurley, pillow, goldman, ballantine,
# Nearest to operations: operation, awd, differentiable, advanced, botswana, fz, rotors, compete,
# Nearest to recorded: roosevelts, elia, rumor, angelina, kroeber, bread, stern, girl,
# Nearest to additional: cavities, pata, lots, fabrics, radiocommunication, cdm, snaps, recombinant,
# Nearest to know: knows, parallels, regarding, woese, signification, harar, embry, doubts,
# Nearest to orthodox: churches, ussher, ordain, antioch, holy, lutherans, spelling, neo,
# Nearest to applications: assemblers, printing, microcode, imac, sugary, bot, hallowed, bundled,
# Nearest to file: compatibility, directory, files, download, ht, packages, communications, adapter,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2389 0.0439 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2246 0.0429 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2236 0.0428 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1524 0.0427 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1991 0.0427 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1776 0.0428 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1667 0.0428 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1821 0.0428 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2016 0.0430 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1812 0.0428 sec/batch
# Nearest to be: would, spectra, mistake, maji, qed, accumulation, nitrides, snark,
# Nearest to from: topsy, gardena, ancestral, winter, vending, chicxulub, native, piercers,
# Nearest to people: parque, identifies, lehman, clips, west, uncertain, ballantine, besht,
# Nearest to that: not, appendant, uninhibited, sacrificed, rebbe, will, compensation, inquire,
# Nearest to an: internally, generalizations, preprocessor, cosmologies, equivalent, variously, trapper, aerial,
# Nearest to war: mightiest, yasser, gonna, carillon, deliberations, charges, pohnpei, army,
# Nearest to they: stranded, rather, keen, armored, inaugurate, foulke, antiretroviral, saved,
# Nearest to with: ede, tireless, soninke, rodham, zug, again, minima, indisputable,
# Nearest to notes: stig, maxims, myth, hurley, jonathan, pillow, authentic, goldman,
# Nearest to operations: operation, awd, advanced, differentiable, fz, compete, army, rotors,
# Nearest to recorded: roosevelts, elia, rumor, bread, kroeber, angelina, stern, hirohito,
# Nearest to additional: cavities, pata, radiocommunication, lots, fabrics, snaps, cdm, asp,
# Nearest to know: knows, parallels, woese, regarding, signification, spatial, harar, multifinder,
# Nearest to orthodox: churches, lutherans, ordain, antioch, ussher, holy, yisrael, oriental,
# Nearest to applications: assemblers, printing, microcode, sugary, imac, hallowed, intermolecular, bot,
# Nearest to file: compatibility, directory, files, ht, download, packages, communications, iota,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1522 0.0437 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2309 0.0428 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1970 0.0428 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1612 0.0426 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2069 0.0427 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1800 0.0427 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1965 0.0430 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1676 0.0426 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1496 0.0429 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1822 0.0429 sec/batch
# Nearest to be: would, spectra, maji, lakshmi, mistake, qed, snark, immigrating,
# Nearest to from: topsy, winter, ancestral, gardena, absolution, subpixel, mogadishu, vanishing,
# Nearest to people: parque, identifies, lehman, clips, uncertain, west, users, besht,
# Nearest to that: not, uninhibited, appendant, sacrificed, rebbe, inquire, humans, compensation,
# Nearest to an: generalizations, aerial, trapper, equivalent, folksong, anode, variously, cosmologies,
# Nearest to war: mightiest, gonna, army, yasser, deliberations, carillon, schwarzenberg, pohnpei,
# Nearest to they: stranded, rather, foulke, inaugurate, awe, armored, keen, vouli,
# Nearest to with: ede, tireless, soninke, rodham, again, obese, minima, zug,
# Nearest to notes: stig, maxims, jonathan, hurley, authentic, myth, naa, pillow,
# Nearest to operations: operation, advanced, awd, fz, gaza, botswana, army, rotors,
# Nearest to recorded: roosevelts, elia, rumor, kroeber, witch, stern, deserters, hirohito,
# Nearest to additional: cavities, pata, fabrics, lots, radiocommunication, cdm, recombinant, asp,
# Nearest to know: knows, parallels, woese, signification, regarding, despair, harar, multifinder,
# Nearest to orthodox: churches, lutherans, antioch, ussher, ordain, yisrael, holy, oriental,
# Nearest to applications: assemblers, printing, microcode, sugary, hallowed, intermolecular, bot, imac,
# Nearest to file: compatibility, directory, files, ht, packages, download, rfc, communications,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2141 0.0439 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1652 0.0429 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1695 0.0428 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1856 0.0429 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1450 0.0428 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1218 0.0428 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1927 0.0429 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1066 0.0430 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1952 0.0429 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2001 0.0428 sec/batch
# Nearest to be: would, psalms, lakshmi, mistake, offend, immigrating, qed, coward,
# Nearest to from: winter, topsy, ancestral, mogadishu, of, native, absolution, empire,
# Nearest to people: parque, lehman, identifies, clips, west, uncertain, besht, dominican,
# Nearest to that: not, uninhibited, appendant, sacrificed, rebbe, compensation, renegade, achaemenids,
# Nearest to an: folksong, generalizations, aerial, trapper, anthony, bisexuality, sorbs, variously,
# Nearest to war: mightiest, schwarzenberg, army, gonna, pohnpei, carillon, yasser, charges,
# Nearest to they: stranded, rather, latinos, vouli, keen, foulke, bukhari, imad,
# Nearest to with: ede, tireless, soninke, again, rodham, ineffectiveness, locker, jia,
# Nearest to notes: stig, hurley, naa, pillow, jonathan, maxims, logographic, authentic,
# Nearest to operations: operation, army, fz, gaza, awd, botswana, advanced, clique,
# Nearest to recorded: roosevelts, elia, rumor, kroeber, witch, girl, hirohito, bread,
# Nearest to additional: cavities, pata, radiocommunication, lots, fabrics, asp, cdm, sympathizers,
# Nearest to know: knows, parallels, woese, regarding, despair, multifinder, signification, harar,
# Nearest to orthodox: churches, lutherans, ussher, yisrael, ordain, antioch, arianism, spelling,
# Nearest to applications: assemblers, printing, microcode, sugary, hallowed, bot, mfm, imac,
# Nearest to file: compatibility, directory, files, ht, packages, rfc, download, preamplifier,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2096 0.0438 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1049 0.0429 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1383 0.0426 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1347 0.0426 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0468 0.0430 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1536 0.0429 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1453 0.0428 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1213 0.0430 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1739 0.0100 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1088 0.0430 sec/batch
# Nearest to be: would, lakshmi, exact, qed, ecu, pseudocode, mistake, floppies,
# Nearest to from: winter, native, gardena, ancestral, piercers, chicxulub, studying, with,
# Nearest to people: parque, lehman, identifies, uncertain, clips, west, besht, siberian,
# Nearest to that: not, uninhibited, appendant, compensation, sacrificed, renegade, absolutely, middleware,
# Nearest to an: generalizations, ino, aerial, trapper, equivalent, internally, bisexuality, sorbs,
# Nearest to war: mightiest, gonna, schwarzenberg, possessed, pohnpei, elas, yasser, deliberations,
# Nearest to they: stranded, rather, latinos, foulke, antiretroviral, imad, vouli, inaugurate,
# Nearest to with: tireless, ede, soninke, colonization, rodham, again, locker, minima,
# Nearest to notes: stig, hurley, jonathan, naa, melody, logographic, key, pillow,
# Nearest to operations: operation, army, awd, fz, clique, botswana, unitary, advanced,
# Nearest to recorded: roosevelts, elia, kroeber, rumor, witch, originals, girl, bread,
# Nearest to additional: cavities, pata, radiocommunication, fabrics, lots, snaps, asp, recombinant,
# Nearest to know: knows, parallels, signification, despair, regarding, multifinder, woese, harar,
# Nearest to orthodox: churches, yisrael, ussher, lutherans, ordain, antioch, arianism, spelling,
# Nearest to applications: assemblers, printing, microcode, imac, sugary, bot, hallowed, tools,
# Nearest to file: compatibility, directory, files, ht, rfc, packages, download, ietf,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0366 0.0441 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0638 0.0430 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0961 0.0430 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0470 0.0430 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0523 0.0430 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0269 0.0430 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1050 0.0429 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0942 0.0429 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1063 0.0430 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0204 0.0430 sec/batch
# Nearest to be: would, lakshmi, maji, woven, exact, nitrides, immigrating, mistake,
# Nearest to from: winter, of, native, with, virtually, ancestral, subpixel, vending,
# Nearest to people: identifies, parque, uncertain, lehman, clips, besht, there, west,
# Nearest to that: not, uninhibited, absolutely, appendant, sacrificed, renegade, if, compensation,
# Nearest to an: generalizations, aerial, trapper, defenseless, variously, sorbs, ino, pear,
# Nearest to war: mightiest, schwarzenberg, elas, gonna, yasser, possessed, pohnpei, tyrannical,
# Nearest to they: stranded, rather, latinos, foulke, armored, keen, vouli, antiretroviral,
# Nearest to with: tireless, ede, soninke, colonization, locker, again, from, ineffectiveness,
# Nearest to notes: stig, key, pillow, hurley, melody, negotiator, pejoratively, jonathan,
# Nearest to operations: operation, army, awd, advanced, clique, implementations, unitary, fz,
# Nearest to recorded: roosevelts, elia, kroeber, rumor, originals, bread, witch, amerikkka,
# Nearest to additional: cavities, pata, radiocommunication, lots, fabrics, snaps, asp, sp,
# Nearest to know: knows, signification, despair, multifinder, regarding, parallels, flaps, harar,
# Nearest to orthodox: churches, yisrael, ordain, lutherans, ussher, antioch, arianism, holy,
# Nearest to applications: assemblers, printing, microcode, imac, hallowed, bot, bundled, sugary,
# Nearest to file: compatibility, files, directory, ht, rfc, packages, download, preamplifier,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0026 0.0440 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0563 0.0429 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0278 0.0427 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0538 0.0430 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0637 0.0430 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0559 0.0431 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0822 0.0430 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0933 0.0429 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0401 0.0430 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0385 0.0431 sec/batch
# Nearest to be: would, woven, lakshmi, maji, pseudocode, accumulation, exact, immigrating,
# Nearest to from: native, winter, of, with, studying, topsy, ancestral, gardena,
# Nearest to people: identifies, lehman, parque, uncertain, clips, besht, there, complementary,
# Nearest to that: not, absolutely, appendant, middleware, renegade, uninhibited, the, if,
# Nearest to an: generalizations, anode, preprocessor, corresponds, ino, algol, cosmologies, folksong,
# Nearest to war: mightiest, schwarzenberg, elas, possessed, gonna, yasser, pohnpei, deliberations,
# Nearest to they: stranded, rather, foulke, latinos, keen, awe, imad, bukhari,
# Nearest to with: tireless, ede, minima, soninke, locker, as, obese, ineffectiveness,
# Nearest to notes: stig, pejoratively, key, logographic, melody, naa, unfolding, hurley,
# Nearest to operations: operation, army, awd, clique, fz, advanced, unitary, implementations,
# Nearest to recorded: roosevelts, elia, kroeber, originals, rumor, desiree, presley, deserters,
# Nearest to additional: cavities, pata, radiocommunication, lots, asp, fabrics, presque, recombinant,
# Nearest to know: knows, signification, multifinder, despair, flaps, parallels, compelling, doesn,
# Nearest to orthodox: churches, ordain, yisrael, lutherans, antioch, ussher, arianism, unremarkable,
# Nearest to applications: assemblers, printing, hallowed, imac, microcode, bot, sugary, queueing,
# Nearest to file: compatibility, files, directory, rfc, ht, preamplifier, download, ietf,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0451 0.0440 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0880 0.0429 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0904 0.0428 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0498 0.0429 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0502 0.0431 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0646 0.0428 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0560 0.0429 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0401 0.0430 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0766 0.0431 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0520 0.0434 sec/batch
# Nearest to be: would, lakshmi, maji, mistake, woven, tartaglia, ethos, exalts,
# Nearest to from: native, of, with, and, winter, studying, frankish, weddell,
# Nearest to people: parque, uncertain, identifies, lehman, clips, dominican, west, there,
# Nearest to that: not, uninhibited, absolutely, renegade, appendant, sacrificed, nuanced, peshitta,
# Nearest to an: generalizations, folksong, defenseless, variously, aerial, anthony, bisexuality, ino,
# Nearest to war: mightiest, elas, schwarzenberg, possessed, yasser, pohnpei, army, deliberations,
# Nearest to they: stranded, rather, bukhari, latinos, vouli, foulke, keen, maltin,
# Nearest to with: tireless, ede, from, ineffectiveness, soninke, locker, obese, as,
# Nearest to notes: stig, melody, pejoratively, key, logographic, naa, negotiator, pillow,
# Nearest to operations: operation, army, fz, awd, zaire, destroyers, gaza, unitary,
# Nearest to recorded: roosevelts, elia, kroeber, originals, desiree, septentrional, shalom, hirohito,
# Nearest to additional: cavities, radiocommunication, pata, lots, asp, recombinant, fabrics, dzogchen,
# Nearest to know: knows, multifinder, despair, signification, parallels, doesn, flaps, regarding,
# Nearest to orthodox: ordain, churches, yisrael, antioch, lutherans, arianism, ussher, unremarkable,
# Nearest to applications: assemblers, printing, hallowed, microcode, sugary, randall, bot, imac,
# Nearest to file: files, compatibility, directory, rfc, ht, download, preamplifier, hfs,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.1026 0.0440 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0131 0.0432 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0198 0.0431 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0584 0.0434 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0553 0.0431 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1388 0.0430 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1225 0.0429 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0353 0.0429 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0312 0.0428 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0474 0.0428 sec/batch
# Nearest to be: would, lakshmi, mistake, maji, reactivation, tartaglia, offend, ethos,
# Nearest to from: of, native, winter, with, and, gnome, weddell, gardena,
# Nearest to people: lehman, parque, clips, uncertain, dominican, americans, identifies, west,
# Nearest to that: not, uninhibited, absolutely, renegade, middleware, if, appendant, unimpeded,
# Nearest to an: generalizations, defenseless, aerial, folksong, trapper, ino, equivalent, anode,
# Nearest to war: mightiest, elas, pohnpei, schwarzenberg, yasser, truce, gonna, negus,
# Nearest to they: stranded, rather, bukhari, latinos, vouli, awe, foulke, imad,
# Nearest to with: ede, tireless, locker, from, ineffectiveness, as, minima, obese,
# Nearest to notes: stig, naa, pejoratively, melody, negotiator, tristan, unfolding, key,
# Nearest to operations: operation, army, destroyers, fz, awd, clique, unitary, gaza,
# Nearest to recorded: roosevelts, elia, kroeber, desiree, septentrional, originals, shalom, amerikkka,
# Nearest to additional: cavities, radiocommunication, lots, sympathizers, pata, dzogchen, snaps, recombinant,
# Nearest to know: knows, despair, multifinder, doesn, regarding, think, dystopic, embry,
# Nearest to orthodox: yisrael, ordain, churches, lutherans, unremarkable, antioch, ussher, arianism,
# Nearest to applications: assemblers, printing, hallowed, microcode, tools, bot, randall, voip,
# Nearest to file: directory, files, compatibility, rfc, ht, preamplifier, download, hfs,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9841 0.0440 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0245 0.0433 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0189 0.0431 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0251 0.0429 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0714 0.0431 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0274 0.0422 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9774 0.0430 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9704 0.0430 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0252 0.0430 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9869 0.0432 sec/batch
# Nearest to be: would, lakshmi, maji, mistake, woven, livelihoods, pseudocode, ethos,
# Nearest to from: native, with, and, of, winter, gnome, membranes, piercers,
# Nearest to people: parque, uncertain, clips, identifies, lehman, americans, besht, dominican,
# Nearest to that: not, renegade, uninhibited, absolutely, appendant, humans, making, middleware,
# Nearest to an: defenseless, generalizations, aerial, folksong, ino, equivalent, pear, juche,
# Nearest to war: mightiest, pohnpei, schwarzenberg, elas, nizkor, gonna, possessed, yasser,
# Nearest to they: stranded, latinos, rather, bukhari, foulke, armored, inaugurate, maltin,
# Nearest to with: as, tireless, ede, from, locker, ineffectiveness, soninke, represent,
# Nearest to notes: stig, melody, naa, pejoratively, key, unfolding, eliyahu, negotiator,
# Nearest to operations: operation, army, clique, destroyers, awd, fz, torpedo, mapping,
# Nearest to recorded: roosevelts, elia, kroeber, shalom, septentrional, originals, amerikkka, tombigbee,
# Nearest to additional: cavities, radiocommunication, lots, herrn, seldom, asp, dzogchen, presque,
# Nearest to know: despair, knows, doesn, think, signification, multifinder, parallels, dystopic,
# Nearest to orthodox: ordain, yisrael, churches, unremarkable, lutherans, antioch, ussher, arianism,
# Nearest to applications: printing, assemblers, hallowed, randall, bot, tools, queueing, voip,
# Nearest to file: files, directory, compatibility, rfc, hfs, preamplifier, ht, download,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9790 0.0438 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9403 0.0429 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0481 0.0428 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0177 0.0427 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0313 0.0428 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9858 0.0431 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8991 0.0432 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9808 0.0432 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9256 0.0429 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9790 0.0433 sec/batch
# Nearest to be: would, consider, pseudocode, maji, woven, lakshmi, nitrides, livelihoods,
# Nearest to from: native, and, of, with, a, the, membranes, winter,
# Nearest to people: uncertain, identifies, clips, parque, lehman, americans, besht, dominican,
# Nearest to that: not, absolutely, renegade, again, uninhibited, if, appendant, notoriety,
# Nearest to an: defenseless, generalizations, variously, aerial, variants, varnish, pear, juche,
# Nearest to war: mightiest, elas, pohnpei, nizkor, yasser, deploying, schwarzenberg, airborne,
# Nearest to they: stranded, rather, armored, latinos, colbert, awe, foulke, graze,
# Nearest to with: as, tireless, locker, from, ede, ineffectiveness, replaced, minima,
# Nearest to notes: stig, pejoratively, melody, key, naa, negotiator, unfolding, tristan,
# Nearest to operations: operation, army, awd, clique, torpedo, fz, destroyers, gaza,
# Nearest to recorded: roosevelts, elia, kroeber, originals, desiree, shalom, presley, septentrional,
# Nearest to additional: cavities, dzogchen, radiocommunication, lots, asp, herrn, recombinant, aberrant,
# Nearest to know: doesn, knows, despair, signification, multifinder, think, flaps, i,
# Nearest to orthodox: ordain, yisrael, churches, unremarkable, lutherans, antioch, arianism, ussher,
# Nearest to applications: printing, assemblers, hallowed, queueing, randall, tools, bot, modeled,
# Nearest to file: files, directory, compatibility, rfc, ht, hfs, preamplifier, iota,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9807 0.0441 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9789 0.0428 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9870 0.0428 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0103 0.0428 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0163 0.0432 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9472 0.0431 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9825 0.0432 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9881 0.0433 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0079 0.0428 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9981 0.0426 sec/batch
# Nearest to be: would, consider, lakshmi, mistake, woven, inform, tartaglia, maji,
# Nearest to from: of, and, native, a, with, the, gnome, ancestral,
# Nearest to people: uncertain, parque, clips, identifies, americans, lehman, besht, there,
# Nearest to that: not, absolutely, unimpeded, uninhibited, renegade, if, will, again,
# Nearest to an: generalizations, defenseless, folksong, pear, variously, corresponds, aerial, audible,
# Nearest to war: mightiest, elas, schwarzenberg, pohnpei, nizkor, lemass, yasser, gonna,
# Nearest to they: stranded, rather, latinos, armored, maltin, bukhari, enthusiasts, hamm,
# Nearest to with: as, ede, tireless, from, locker, minima, and, replaced,
# Nearest to notes: stig, key, pejoratively, melody, naa, unfolding, negotiator, eliyahu,
# Nearest to operations: operation, army, awd, clique, fz, zaire, advanced, gaza,
# Nearest to recorded: elia, roosevelts, kroeber, presley, originals, reunited, desiree, shalom,
# Nearest to additional: cavities, radiocommunication, dzogchen, lots, asp, herrn, recombinant, presque,
# Nearest to know: doesn, knows, despair, think, i, signification, any, shall,
# Nearest to orthodox: churches, yisrael, unremarkable, ordain, antioch, lutherans, spelling, oriental,
# Nearest to applications: hallowed, printing, assemblers, randall, queueing, tools, using, voip,
# Nearest to file: files, directory, compatibility, rfc, ht, hfs, preamplifier, ietf,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9916 0.0439 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0018 0.0429 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9686 0.0429 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0175 0.0429 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0313 0.0429 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9702 0.0427 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9706 0.0428 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9575 0.0428 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9750 0.0428 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0512 0.0431 sec/batch
# Nearest to be: mistake, would, chief, inform, consider, lakshmi, pseudocode, reactivation,
# Nearest to from: and, of, the, native, a, with, gnome, ancestral,
# Nearest to people: uncertain, parque, clips, lehman, americans, geneticists, dominican, identifies,
# Nearest to that: not, again, unimpeded, renegade, absolutely, the, humans, uninhibited,
# Nearest to an: generalizations, defenseless, aerial, juche, folksong, corresponds, nan, anthony,
# Nearest to war: mightiest, schwarzenberg, pohnpei, elas, whitefish, fairey, deploying, nizkor,
# Nearest to they: stranded, rather, bukhari, latinos, tolerant, armored, maltin, inheritance,
# Nearest to with: as, from, ede, and, tireless, replaced, soninke, but,
# Nearest to notes: stig, melody, pejoratively, naa, key, unfolding, logographic, tristan,
# Nearest to operations: operation, army, fz, awd, clique, gaza, torpedo, zaire,
# Nearest to recorded: roosevelts, elia, kroeber, shalom, originals, presley, neologisms, desiree,
# Nearest to additional: cavities, radiocommunication, recombinant, asp, lots, dzogchen, aberrant, sibilants,
# Nearest to know: doesn, knows, despair, think, signification, multifinder, flaps, i,
# Nearest to orthodox: unremarkable, yisrael, ordain, churches, antioch, lutherans, wilton, ussher,
# Nearest to applications: hallowed, assemblers, randall, tools, queueing, printing, ethertype, voip,
# Nearest to file: directory, files, compatibility, ht, rfc, hfs, deniers, iota,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9861 0.0442 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0715 0.0428 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7799 0.0419 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7981 0.0421 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8654 0.0422 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8340 0.0422 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8358 0.0421 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8579 0.0421 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8998 0.0421 sec/batch
# Nearest to be: consider, can, may, would, should, have, in, for,
# Nearest to from: the, and, of, a, for, with, is, in,
# Nearest to people: americans, oneself, uncertain, musicians, living, counted, there, rocco,
# Nearest to that: the, not, this, says, it, of, is, some,
# Nearest to an: a, the, with, as, for, also, to, from,
# Nearest to war: world, whitefish, mightiest, fairey, ii, elas, ayyash, truce,
# Nearest to they: their, stranded, have, them, aside, there, urogenital, these,
# Nearest to with: as, and, the, of, an, from, for, also,
# Nearest to notes: melody, eliyahu, historiae, uncomplimentary, landa, bass, polychoral, sou,
# Nearest to operations: operation, dmitri, army, clique, rescue, holistic, zaire, lucent,
# Nearest to recorded: elia, roosevelts, presley, originals, motown, garfunkel, notations, shalom,
# Nearest to additional: dzogchen, cavities, patriarchate, absent, seldom, soo, aberrant, presque,
# Nearest to know: think, doesn, i, speaking, knows, we, yes, things,
# Nearest to orthodox: unremarkable, antioch, yisrael, semiconductors, dogmatic, churches, ordain, wilton,
# Nearest to applications: hallowed, queueing, ethertype, reliably, graphical, tools, randall, exalt,
# Nearest to file: files, directory, deniers, filename, compression, rfc, hfs, iota,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8231 0.0432 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8547 0.0419 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8230 0.0419 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8736 0.0420 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8790 0.0423 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8845 0.0428 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8659 0.0421 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8485 0.0422 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8377 0.0423 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8859 0.0422 sec/batch
# Nearest to be: would, consider, may, in, should, can, have, been,
# Nearest to from: the, a, and, of, with, for, is, in,
# Nearest to people: americans, musicians, uncertain, oneself, living, there, counted, transpersonal,
# Nearest to that: not, the, says, this, again, it, of, some,
# Nearest to an: a, with, the, as, also, for, from, to,
# Nearest to war: mightiest, ii, world, truce, whitefish, elas, fairey, wehrmacht,
# Nearest to they: their, have, stranded, them, aside, there, enthusiasts, these,
# Nearest to with: as, and, from, the, of, an, also, for,
# Nearest to notes: historiae, melody, eliyahu, uncomplimentary, landa, polychoral, unfolding, stig,
# Nearest to operations: operation, army, dmitri, zaire, fz, awd, holistic, clique,
# Nearest to recorded: elia, roosevelts, presley, originals, shalom, notations, fostered, kroeber,
# Nearest to additional: cavities, dzogchen, patriarchate, absent, seldom, recombinant, moonlight, dehydrogenase,
# Nearest to know: think, doesn, speaking, i, knows, we, things, yes,
# Nearest to orthodox: unremarkable, antioch, ordain, dogmatic, churches, semiconductors, yisrael, oriental,
# Nearest to applications: hallowed, ethertype, randall, queueing, tools, laser, reliably, graphical,
# Nearest to file: files, directory, filename, compression, rfc, hfs, deniers, iota,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8535 0.0434 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8291 0.0422 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8282 0.0424 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8000 0.0421 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8951 0.0422 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8393 0.0421 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9540 0.0421 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8924 0.0421 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9048 0.0421 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8132 0.0421 sec/batch
# Nearest to be: would, consider, may, can, have, should, in, been,
# Nearest to from: the, and, a, of, with, is, for, in,
# Nearest to people: americans, oneself, living, uncertain, alumni, musicians, counted, natives,
# Nearest to that: not, says, the, it, this, of, some, to,
# Nearest to an: the, with, a, as, for, also, from, to,
# Nearest to war: world, mightiest, ii, whitefish, fairey, elas, truce, announces,
# Nearest to they: their, them, have, stranded, there, aside, excluded, some,
# Nearest to with: as, and, from, the, an, of, also, for,
# Nearest to notes: eliyahu, landa, melody, historiae, uncomplimentary, polychoral, zondervan, negotiator,
# Nearest to operations: operation, army, dmitri, svr, rescue, awd, fz, zaire,
# Nearest to recorded: elia, roosevelts, presley, originals, kroeber, fostered, tombigbee, shalom,
# Nearest to additional: cavities, dzogchen, patriarchate, absent, seldom, consists, soo, dehydrogenase,
# Nearest to know: think, doesn, i, speaking, knows, yes, you, we,
# Nearest to orthodox: unremarkable, antioch, yisrael, semiconductors, dogmatic, ordain, wilton, judaism,
# Nearest to applications: hallowed, randall, ethertype, queueing, reliably, laser, tools, graphical,
# Nearest to file: files, directory, compression, deniers, filename, iota, hfs, rfc,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7910 0.0427 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8431 0.0421 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7785 0.0421 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8507 0.0422 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8294 0.0423 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8354 0.0420 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8605 0.0284 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8294 0.0421 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8220 0.0421 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8652 0.0422 sec/batch
# Nearest to be: would, been, may, can, consider, should, in, have,
# Nearest to from: the, and, of, a, with, is, for, an,
# Nearest to people: americans, oneself, living, musicians, counted, uncertain, alumni, dpp,
# Nearest to that: not, the, says, of, this, as, it, to,
# Nearest to an: the, a, as, with, for, also, from, to,
# Nearest to war: world, whitefish, ii, mightiest, elas, fairey, announces, gains,
# Nearest to they: their, them, stranded, aside, have, these, there, excluded,
# Nearest to with: as, and, the, of, from, an, for, also,
# Nearest to notes: eliyahu, melody, landa, historiae, uncomplimentary, shall, polychoral, zondervan,
# Nearest to operations: operation, army, svr, holistic, dmitri, rescue, watchmakers, clique,
# Nearest to recorded: roosevelts, elia, presley, originals, fostered, shalom, tombigbee, from,
# Nearest to additional: cavities, dzogchen, patriarchate, absent, seldom, consists, moonlight, yin,
# Nearest to know: think, doesn, speaking, things, i, knows, we, yes,
# Nearest to orthodox: unremarkable, yisrael, semiconductors, wilton, churches, antioch, ordain, judaism,
# Nearest to applications: hallowed, ethertype, queueing, randall, tools, reliably, bot, laser,
# Nearest to file: files, directory, compression, hfs, iota, filename, folder, deniers,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7886 0.0430 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8372 0.0420 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7752 0.0420 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8340 0.0420 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8250 0.0419 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8132 0.0419 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8442 0.0421 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7218 0.0421 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8096 0.0420 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7684 0.0420 sec/batch
# Nearest to be: can, would, consider, may, should, have, for, in,
# Nearest to from: the, of, and, a, for, with, is, in,
# Nearest to people: americans, oneself, musicians, living, counted, uncertain, alumni, suicides,
# Nearest to that: not, the, says, this, it, again, of, to,
# Nearest to an: the, a, with, as, for, also, from, to,
# Nearest to war: elas, whitefish, world, mightiest, ii, fairey, announces, truce,
# Nearest to they: their, aside, stranded, them, there, have, these, excluded,
# Nearest to with: as, and, an, the, of, from, also, for,
# Nearest to notes: melody, eliyahu, shall, sou, uncomplimentary, historiae, landa, polychoral,
# Nearest to operations: operation, holistic, svr, army, dmitri, rescue, lucent, awd,
# Nearest to recorded: elia, roosevelts, presley, originals, fostered, tombigbee, sessions, notations,
# Nearest to additional: cavities, dzogchen, patriarchate, absent, seldom, soo, moonlight, consists,
# Nearest to know: think, doesn, i, speaking, things, knows, we, yes,
# Nearest to orthodox: unremarkable, yisrael, ordain, antioch, dogmatic, semiconductors, judaism, churches,
# Nearest to applications: hallowed, ethertype, queueing, tools, bot, laser, reliably, randall,
# Nearest to file: files, directory, compression, hfs, iota, filename, folder, caucasus,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7860 0.0431 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8152 0.0419 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8543 0.0419 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8074 0.0419 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8266 0.0421 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8831 0.0420 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8025 0.0423 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8175 0.0421 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8118 0.0419 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8184 0.0419 sec/batch
# Nearest to be: can, would, may, consider, in, should, have, for,
# Nearest to from: the, of, and, a, is, in, with, for,
# Nearest to people: americans, oneself, musicians, dpp, living, uncertain, alumni, counted,
# Nearest to that: not, says, the, it, this, some, of, is,
# Nearest to an: a, the, with, as, also, for, and, of,
# Nearest to war: whitefish, mightiest, world, elas, announces, ii, flickering, truce,
# Nearest to they: their, aside, them, stranded, have, enthusiasts, excluded, urogenital,
# Nearest to with: as, and, of, an, the, also, for, from,
# Nearest to notes: eliyahu, melody, historiae, uncomplimentary, shall, sou, landa, polychoral,
# Nearest to operations: operation, rescue, svr, holistic, dmitri, army, lucent, counterattacks,
# Nearest to recorded: presley, elia, originals, roosevelts, fostered, notations, shalom, sessions,
# Nearest to additional: patriarchate, cavities, dzogchen, absent, seldom, soo, dehydrogenase, consists,
# Nearest to know: think, doesn, we, i, knows, things, speaking, yes,
# Nearest to orthodox: unremarkable, churches, ordain, antioch, yisrael, dogmatic, semiconductors, oriental,
# Nearest to applications: hallowed, ethertype, randall, reliably, queueing, laser, bot, technical,
# Nearest to file: files, directory, filename, compression, hfs, folder, caucasus, deniers,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8127 0.0430 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8400 0.0421 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8376 0.0420 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8221 0.0418 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8368 0.0421 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8402 0.0424 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8492 0.0422 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8246 0.0422 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8126 0.0421 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8144 0.0420 sec/batch
# Nearest to be: may, would, for, can, have, should, in, consider,
# Nearest to from: the, of, and, a, with, in, for, as,
# Nearest to people: americans, musicians, uncertain, oneself, living, natives, nation, dpp,
# Nearest to that: not, the, it, this, says, of, on, as,
# Nearest to an: a, the, with, also, as, for, and, of,
# Nearest to war: whitefish, mightiest, world, ii, elas, announces, truce, flickering,
# Nearest to they: their, aside, them, stranded, these, have, enthusiasts, there,
# Nearest to with: as, and, an, of, the, from, for, also,
# Nearest to notes: melody, eliyahu, uncomplimentary, sou, shall, historiae, landa, bass,
# Nearest to operations: operation, rescue, svr, army, dmitri, holistic, counterattacks, employees,
# Nearest to recorded: presley, originals, elia, roosevelts, shalom, apostolicity, fostered, isotopes,
# Nearest to additional: patriarchate, dzogchen, cavities, seldom, absent, dehydrogenase, consists, soo,
# Nearest to know: think, doesn, we, speaking, knows, yes, things, i,
# Nearest to orthodox: unremarkable, antioch, yisrael, ordain, semiconductors, churches, dogmatic, judaism,
# Nearest to applications: hallowed, ethertype, randall, reliably, queueing, technical, bot, laser,
# Nearest to file: files, directory, hfs, compression, folder, filename, iota, caucasus,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8499 0.0432 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8278 0.0424 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9403 0.0423 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9034 0.0424 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8921 0.0422 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8109 0.0421 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7691 0.0420 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8305 0.0420 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7362 0.0423 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8660 0.0421 sec/batch
# Nearest to be: consider, may, can, would, for, have, been, should,
# Nearest to from: the, and, of, a, with, is, in, for,
# Nearest to people: americans, musicians, living, alumni, uncertain, natives, dpp, oneself,
# Nearest to that: not, it, the, this, says, some, is, as,
# Nearest to an: a, with, the, also, as, for, from, and,
# Nearest to war: whitefish, world, elas, ii, announces, mightiest, truce, fairey,
# Nearest to they: their, aside, them, stranded, there, have, some, these,
# Nearest to with: and, as, an, from, also, the, of, for,
# Nearest to notes: melody, uncomplimentary, shall, eliyahu, polychoral, historiae, sou, landa,
# Nearest to operations: operation, rescue, svr, dmitri, holistic, army, counterattacks, clique,
# Nearest to recorded: presley, elia, roosevelts, originals, sessions, shalom, fostered, tombigbee,
# Nearest to additional: patriarchate, cavities, dzogchen, seldom, soo, absent, which, dehydrogenase,
# Nearest to know: think, doesn, we, knows, things, speaking, yes, i,
# Nearest to orthodox: unremarkable, yisrael, antioch, semiconductors, ordain, dogmatic, judaism, punches,
# Nearest to applications: hallowed, ethertype, reliably, tools, queueing, laser, randall, unconventional,
# Nearest to file: files, directory, hfs, folder, compression, iota, filename, caucasus,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8527 0.0433 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8194 0.0420 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 100
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
viz_words
# Out:
# 500

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([31, 64, 57, 72, 76, 61, 74,  1, 16,  0,  0,  0, 36, 57, 72, 72, 81,
#         1, 62, 57, 69, 65, 68, 65, 61, 75,  1, 57, 74, 61,  1, 57, 68, 68,
#         1, 57, 68, 65, 67, 61, 26,  1, 61, 78, 61, 74, 81,  1, 77, 70, 64,
#        57, 72, 72, 81,  1, 62, 57, 69, 65, 68, 81,  1, 65, 75,  1, 77, 70,
#        64, 57, 72, 72, 81,  1, 65, 70,  1, 65, 76, 75,  1, 71, 79, 70,  0,
#        79, 57, 81, 13,  0,  0, 33, 78, 61, 74, 81, 76, 64, 65, 70], dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
#
# We start with our text encoded as integers in one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the total number of batches, $K$, we can make from the array `arr`, you divide the length of `arr` by the number of characters per batch. Once you know the number of batches, you can get the total number of characters to keep from `arr`, $N * M * K$.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`batch_size` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the $N \times (M * K)$ array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, batch_size, n_steps):
    '''Create a generator that returns batches of size
       batch_size x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       batch_size: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = int(len(arr)/batch_size)
    n_batches = int(characters_per_batch/n_steps)
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches*n_steps*batch_size]
    
    # Reshape into batch_size rows: why batch_size rows? Tis exactly the number of sequence in one batch. Hence the number of rows.
    # [1,2,3,4,5,6]
    # [1,2,3,4,5,6]
    # first batch has two seuqence: [1,2,3], [1,2,3]
    arr = arr.reshape([batch_size, -1])
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        # the following code is to take care of the last elementin y, as the last y array will lack of 1 column.
        # this code makes the last column to be 0
        y_tmp = arr[:, n+1:n+1+n_steps]
        y = np.zeros(x.shape, dtype=x.dtype)
        y[:, :y_tmp.shape[1]] = y_tmp
        
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[31 64 57 72 76 61 74  1 16  0]
#  [ 1 57 69  1 70 71 76  1 63 71]
#  [78 65 70 13  0  0  3 53 61 75]
#  [70  1 60 77 74 65 70 63  1 64]
#  [ 1 65 76  1 65 75 11  1 75 65]
#  [ 1 37 76  1 79 57 75  0 71 70]
#  [64 61 70  1 59 71 69 61  1 62]
#  [26  1 58 77 76  1 70 71 79  1]
#  [76  1 65 75 70  7 76 13  1 48]
#  [ 1 75 57 65 60  1 76 71  1 64]]
#
# y
#  [[64 57 72 76 61 74  1 16  0  0]
#  [57 69  1 70 71 76  1 63 71 65]
#  [65 70 13  0  0  3 53 61 75 11]
#  [ 1 60 77 74 65 70 63  1 64 65]
#  [65 76  1 65 75 11  1 75 65 74]
#  [37 76  1 79 57 75  0 71 70 68]
#  [61 70  1 59 71 69 61  1 62 71]
#  [ 1 58 77 76  1 70 71 79  1 75]
#  [ 1 65 75 70  7 76 13  1 48 64]
#  [75 57 65 60  1 76 71  1 64 61]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
    '''
    # Declare placeholders we'll feed into the graph
    inputs  = tf.placeholder(tf.int32, shape=(batch_size, num_steps), name = "inputs")
    targets = tf.placeholder(tf.int32, shape=(batch_size, num_steps), name = "targets")

    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name = "keep_prob") # this is a scalar
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    def build_cell(lstm_size, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        # Add dropout to the cell outputs
        # drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        
        return lstm
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer: how many vocalbulary we have
    
    '''

    #### THE SIZING HERE IS QUITE CONFUSING
    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # Concatenate lstm_output over axis 1 (the columns)
    seq_output = tf.concat(lstm_output, axis = 1, name = "seq_output")
    # Reshape seq_output to a 2D tensor with lstm_size columns
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        # Create the weight and bias variables here
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per sequence per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped =  tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn 
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state = self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 10         # Sequences per batch
num_steps = 50          # Number of sequence steps per batch
lstm_size = 128         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.01    # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Print losses every N interations
print_every_n = 50

# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            if (counter % print_every_n == 0):
                end = time.time()
                print('Epoch: {}/{}... '.format(e+1, epochs),
                      'Training Step: {}... '.format(counter),
                      'Training loss: {:.4f}... '.format(batch_loss),
                      '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.0831...  0.0444 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 2.4278...  0.0418 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.1785...  0.0439 sec/batch
# Epoch: 1/20...  Training Step: 200...  Training loss: 2.2065...  0.0441 sec/batch
# Epoch: 1/20...  Training Step: 250...  Training loss: 2.1006...  0.0408 sec/batch
# Epoch: 1/20...  Training Step: 300...  Training loss: 1.9682...  0.0425 sec/batch
# Epoch: 1/20...  Training Step: 350...  Training loss: 1.8990...  0.0446 sec/batch
# Epoch: 1/20...  Training Step: 400...  Training loss: 1.8605...  0.0414 sec/batch
# Epoch: 1/20...  Training Step: 450...  Training loss: 1.9350...  0.0438 sec/batch
# Epoch: 1/20...  Training Step: 500...  Training loss: 1.9402...  0.0417 sec/batch
# Epoch: 1/20...  Training Step: 550...  Training loss: 1.6836...  0.0434 sec/batch
# Epoch: 1/20...  Training Step: 600...  Training loss: 1.6429...  0.0419 sec/batch
# Epoch: 1/20...  Training Step: 650...  Training loss: 1.6001...  0.0417 sec/batch
# Epoch: 1/20...  Training Step: 700...  Training loss: 1.6102...  0.0423 sec/batch
# Epoch: 1/20...  Training Step: 750...  Training loss: 1.7014...  0.0413 sec/batch
# Epoch: 1/20...  Training Step: 800...  Training loss: 1.6338...  0.0423 sec/batch
# Epoch: 1/20...  Training Step: 850...  Training loss: 1.7629...  0.0423 sec/batch
# Epoch: 1/20...  Training Step: 900...  Training loss: 1.6635...  0.0444 sec/batch
# Epoch: 1/20...  Training Step: 950...  Training loss: 1.6358...  0.0410 sec/batch
# Epoch: 1/20...  Training Step: 1000...  Training loss: 1.6289...  0.0417 sec/batch
# Epoch: 1/20...  Training Step: 1050...  Training loss: 1.5918...  0.0418 sec/batch
# Epoch: 1/20...  Training Step: 1100...  Training loss: 1.5752...  0.0413 sec/batch
# Epoch: 1/20...  Training Step: 1150...  Training loss: 1.5579...  0.0443 sec/batch
# Epoch: 1/20...  Training Step: 1200...  Training loss: 1.5345...  0.0443 sec/batch
# Epoch: 1/20...  Training Step: 1250...  Training loss: 1.3567...  0.0445 sec/batch
# Epoch: 1/20...  Training Step: 1300...  Training loss: 1.5411...  0.0425 sec/batch
# Epoch: 1/20...  Training Step: 1350...  Training loss: 1.4402...  0.0440 sec/batch
# Epoch: 1/20...  Training Step: 1400...  Training loss: 1.6874...  0.0421 sec/batch
# Epoch: 1/20...  Training Step: 1450...  Training loss: 1.5431...  0.0413 sec/batch
# Epoch: 1/20...  Training Step: 1500...  Training loss: 1.5728...  0.0424 sec/batch
# Epoch: 1/20...  Training Step: 1550...  Training loss: 1.4532...  0.0443 sec/batch
# Epoch: 1/20...  Training Step: 1600...  Training loss: 1.5237...  0.0412 sec/batch
# Epoch: 1/20...  Training Step: 1650...  Training loss: 1.4328...  0.0418 sec/batch
# Epoch: 1/20...  Training Step: 1700...  Training loss: 1.4809...  0.0422 sec/batch
# Epoch: 1/20...  Training Step: 1750...  Training loss: 1.5417...  0.0418 sec/batch
# Epoch: 1/20...  Training Step: 1800...  Training loss: 1.5412...  0.0440 sec/batch
# Epoch: 1/20...  Training Step: 1850...  Training loss: 1.5579...  0.0421 sec/batch
# Epoch: 1/20...  Training Step: 1900...  Training loss: 1.2426...  0.0416 sec/batch
# Epoch: 1/20...  Training Step: 1950...  Training loss: 1.4409...  0.0419 sec/batch
# Epoch: 1/20...  Training Step: 2000...  Training loss: 1.4597...  0.0430 sec/batch
# Epoch: 1/20...  Training Step: 2050...  Training loss: 1.6249...  0.0418 sec/batch
# Epoch: 1/20...  Training Step: 2100...  Training loss: 1.4327...  0.0416 sec/batch
# Epoch: 1/20...  Training Step: 2150...  Training loss: 1.5123...  0.0424 sec/batch
# Epoch: 1/20...  Training Step: 2200...  Training loss: 1.4353...  0.0420 sec/batch
# Epoch: 1/20...  Training Step: 2250...  Training loss: 1.4926...  0.0416 sec/batch
# Epoch: 1/20...  Training Step: 2300...  Training loss: 1.3255...  0.0423 sec/batch
# Epoch: 1/20...  Training Step: 2350...  Training loss: 1.5423...  0.0421 sec/batch
# Epoch: 1/20...  Training Step: 2400...  Training loss: 1.5314...  0.0445 sec/batch
# Epoch: 1/20...  Training Step: 2450...  Training loss: 1.5500...  0.0416 sec/batch
# Epoch: 1/20...  Training Step: 2500...  Training loss: 1.4082...  0.0416 sec/batch
# Epoch: 1/20...  Training Step: 2550...  Training loss: 1.4295...  0.0421 sec/batch
# Epoch: 1/20...  Training Step: 2600...  Training loss: 1.4094...  0.0416 sec/batch
# Epoch: 1/20...  Training Step: 2650...  Training loss: 1.5172...  0.0425 sec/batch
# Epoch: 1/20...  Training Step: 2700...  Training loss: 1.5111...  0.0419 sec/batch
# Epoch: 1/20...  Training Step: 2750...  Training loss: 1.2993...  0.0437 sec/batch
# Epoch: 1/20...  Training Step: 2800...  Training loss: 1.1753...  0.0427 sec/batch
# Epoch: 1/20...  Training Step: 2850...  Training loss: 1.5445...  0.0441 sec/batch
# Epoch: 1/20...  Training Step: 2900...  Training loss: 1.2231...  0.0420 sec/batch
# Epoch: 1/20...  Training Step: 2950...  Training loss: 1.2324...  0.0446 sec/batch
# Epoch: 1/20...  Training Step: 3000...  Training loss: 1.3817...  0.0420 sec/batch
# Epoch: 1/20...  Training Step: 3050...  Training loss: 1.5454...  0.0439 sec/batch
# Epoch: 1/20...  Training Step: 3100...  Training loss: 1.3761...  0.0452 sec/batch
# Epoch: 1/20...  Training Step: 3150...  Training loss: 1.3134...  0.0422 sec/batch
# Epoch: 1/20...  Training Step: 3200...  Training loss: 1.4878...  0.0414 sec/batch
# Epoch: 1/20...  Training Step: 3250...  Training loss: 1.4418...  0.0418 sec/batch
# Epoch: 1/20...  Training Step: 3300...  Training loss: 1.4215...  0.0448 sec/batch
# Epoch: 1/20...  Training Step: 3350...  Training loss: 1.3151...  0.0423 sec/batch
# Epoch: 1/20...  Training Step: 3400...  Training loss: 1.4707...  0.0434 sec/batch
# Epoch: 1/20...  Training Step: 3450...  Training loss: 1.3092...  0.0444 sec/batch
# Epoch: 1/20...  Training Step: 3500...  Training loss: 1.3362...  0.0438 sec/batch
# Epoch: 1/20...  Training Step: 3550...  Training loss: 1.4351...  0.0413 sec/batch
# Epoch: 1/20...  Training Step: 3600...  Training loss: 1.4283...  0.0441 sec/batch
# Epoch: 1/20...  Training Step: 3650...  Training loss: 1.5428...  0.0420 sec/batch
# Epoch: 1/20...  Training Step: 3700...  Training loss: 1.2676...  0.0415 sec/batch
# Epoch: 1/20...  Training Step: 3750...  Training loss: 1.4213...  0.0414 sec/batch
# Epoch: 1/20...  Training Step: 3800...  Training loss: 1.3086...  0.0420 sec/batch
# Epoch: 1/20...  Training Step: 3850...  Training loss: 1.4214...  0.0439 sec/batch
# Epoch: 1/20...  Training Step: 3900...  Training loss: 1.6173...  0.0424 sec/batch
# Epoch: 1/20...  Training Step: 3950...  Training loss: 1.3498...  0.0413 sec/batch
# Epoch: 2/20...  Training Step: 4000...  Training loss: 1.3676...  0.0412 sec/batch
# Epoch: 2/20...  Training Step: 4050...  Training loss: 1.3286...  0.0411 sec/batch
# Epoch: 2/20...  Training Step: 4100...  Training loss: 1.3375...  0.0444 sec/batch
# Epoch: 2/20...  Training Step: 4150...  Training loss: 1.2573...  0.0421 sec/batch
# Epoch: 2/20...  Training Step: 4200...  Training loss: 1.3737...  0.0438 sec/batch
# Epoch: 2/20...  Training Step: 4250...  Training loss: 1.4403...  0.0453 sec/batch
# Epoch: 2/20...  Training Step: 4300...  Training loss: 1.4498...  0.0423 sec/batch
# Epoch: 2/20...  Training Step: 4350...  Training loss: 1.4542...  0.0434 sec/batch
# Epoch: 2/20...  Training Step: 4400...  Training loss: 1.3312...  0.0443 sec/batch
# Epoch: 2/20...  Training Step: 4450...  Training loss: 1.4268...  0.0428 sec/batch
# Epoch: 2/20...  Training Step: 4500...  Training loss: 1.3919...  0.0420 sec/batch
# Epoch: 2/20...  Training Step: 4550...  Training loss: 1.5893...  0.0411 sec/batch
# Epoch: 2/20...  Training Step: 4600...  Training loss: 1.4582...  0.0423 sec/batch
# Epoch: 2/20...  Training Step: 4650...  Training loss: 1.5264...  0.0419 sec/batch
# Epoch: 2/20...  Training Step: 4700...  Training loss: 1.2991...  0.0418 sec/batch
# Epoch: 2/20...  Training Step: 4750...  Training loss: 1.5360...  0.0417 sec/batch
# Epoch: 2/20...  Training Step: 4800...  Training loss: 1.2854...  0.0447 sec/batch
# Epoch: 2/20...  Training Step: 4850...  Training loss: 1.2254...  0.0417 sec/batch
# Epoch: 2/20...  Training Step: 4900...  Training loss: 1.3421...  0.0422 sec/batch
# Epoch: 2/20...  Training Step: 4950...  Training loss: 1.2951...  0.0417 sec/batch
# Epoch: 2/20...  Training Step: 5000...  Training loss: 1.3544...  0.0427 sec/batch
# Epoch: 2/20...  Training Step: 5050...  Training loss: 1.2293...  0.0425 sec/batch
# Epoch: 2/20...  Training Step: 5100...  Training loss: 1.2066...  0.0424 sec/batch
# Epoch: 2/20...  Training Step: 5150...  Training loss: 1.3564...  0.0411 sec/batch
# Epoch: 2/20...  Training Step: 5200...  Training loss: 1.4156...  0.0439 sec/batch
# Epoch: 2/20...  Training Step: 5250...  Training loss: 1.2366...  0.0441 sec/batch
# Epoch: 2/20...  Training Step: 5300...  Training loss: 1.4183...  0.0427 sec/batch
# Epoch: 2/20...  Training Step: 5350...  Training loss: 1.3086...  0.0416 sec/batch
# Epoch: 2/20...  Training Step: 5400...  Training loss: 1.4102...  0.0429 sec/batch
# Epoch: 2/20...  Training Step: 5450...  Training loss: 1.3538...  0.0412 sec/batch
# Epoch: 2/20...  Training Step: 5500...  Training loss: 1.4212...  0.0450 sec/batch
# Epoch: 2/20...  Training Step: 5550...  Training loss: 1.3438...  0.0442 sec/batch
# Epoch: 2/20...  Training Step: 5600...  Training loss: 1.4595...  0.0441 sec/batch
# Epoch: 2/20...  Training Step: 5650...  Training loss: 1.3074...  0.0421 sec/batch
# Epoch: 2/20...  Training Step: 5700...  Training loss: 1.2675...  0.0407 sec/batch
# Epoch: 2/20...  Training Step: 5750...  Training loss: 1.3015...  0.0421 sec/batch
# Epoch: 2/20...  Training Step: 5800...  Training loss: 1.3941...  0.0438 sec/batch
# Epoch: 2/20...  Training Step: 5850...  Training loss: 1.4434...  0.0428 sec/batch
# Epoch: 2/20...  Training Step: 5900...  Training loss: 1.3005...  0.0440 sec/batch
# Epoch: 2/20...  Training Step: 5950...  Training loss: 1.3124...  0.0444 sec/batch
# Epoch: 2/20...  Training Step: 6000...  Training loss: 1.2832...  0.0417 sec/batch
# Epoch: 2/20...  Training Step: 6050...  Training loss: 1.2701...  0.0420 sec/batch
# Epoch: 2/20...  Training Step: 6100...  Training loss: 1.4289...  0.0442 sec/batch
# Epoch: 2/20...  Training Step: 6150...  Training loss: 1.3581...  0.0427 sec/batch
# Epoch: 2/20...  Training Step: 6200...  Training loss: 1.3563...  0.0426 sec/batch
# Epoch: 2/20...  Training Step: 6250...  Training loss: 1.3139...  0.0423 sec/batch
# Epoch: 2/20...  Training Step: 6300...  Training loss: 1.2384...  0.0412 sec/batch
# Epoch: 2/20...  Training Step: 6350...  Training loss: 1.4088...  0.0439 sec/batch
# Epoch: 2/20...  Training Step: 6400...  Training loss: 1.2382...  0.0441 sec/batch
# Epoch: 2/20...  Training Step: 6450...  Training loss: 1.3198...  0.0450 sec/batch
# Epoch: 2/20...  Training Step: 6500...  Training loss: 1.2446...  0.0411 sec/batch
# Epoch: 2/20...  Training Step: 6550...  Training loss: 1.3748...  0.0426 sec/batch
# Epoch: 2/20...  Training Step: 6600...  Training loss: 1.4892...  0.0418 sec/batch
# Epoch: 2/20...  Training Step: 6650...  Training loss: 1.2389...  0.0423 sec/batch
# Epoch: 2/20...  Training Step: 6700...  Training loss: 1.2849...  0.0425 sec/batch
# Epoch: 2/20...  Training Step: 6750...  Training loss: 1.2813...  0.0419 sec/batch
# Epoch: 2/20...  Training Step: 6800...  Training loss: 1.4199...  0.0410 sec/batch
# Epoch: 2/20...  Training Step: 6850...  Training loss: 1.3661...  0.0426 sec/batch
# Epoch: 2/20...  Training Step: 6900...  Training loss: 1.2458...  0.0417 sec/batch
# Epoch: 2/20...  Training Step: 6950...  Training loss: 1.5300...  0.0427 sec/batch
# Epoch: 2/20...  Training Step: 7000...  Training loss: 1.3510...  0.0420 sec/batch
# Epoch: 2/20...  Training Step: 7050...  Training loss: 1.3009...  0.0442 sec/batch
# Epoch: 2/20...  Training Step: 7100...  Training loss: 1.2337...  0.0415 sec/batch
# Epoch: 2/20...  Training Step: 7150...  Training loss: 1.2186...  0.0437 sec/batch
# Epoch: 2/20...  Training Step: 7200...  Training loss: 1.3641...  0.0445 sec/batch
# Epoch: 2/20...  Training Step: 7250...  Training loss: 1.2158...  0.0437 sec/batch
# Epoch: 2/20...  Training Step: 7300...  Training loss: 1.4607...  0.0426 sec/batch
# Epoch: 2/20...  Training Step: 7350...  Training loss: 1.3100...  0.0439 sec/batch
# Epoch: 2/20...  Training Step: 7400...  Training loss: 1.2264...  0.0418 sec/batch
# Epoch: 2/20...  Training Step: 7450...  Training loss: 1.1220...  0.0417 sec/batch
# Epoch: 2/20...  Training Step: 7500...  Training loss: 1.2543...  0.0421 sec/batch
# Epoch: 2/20...  Training Step: 7550...  Training loss: 1.1857...  0.0427 sec/batch
# Epoch: 2/20...  Training Step: 7600...  Training loss: 1.2879...  0.0413 sec/batch
# Epoch: 2/20...  Training Step: 7650...  Training loss: 1.4737...  0.0420 sec/batch
# Epoch: 2/20...  Training Step: 7700...  Training loss: 1.4328...  0.0438 sec/batch
# Epoch: 2/20...  Training Step: 7750...  Training loss: 1.5732...  0.0415 sec/batch
# Epoch: 2/20...  Training Step: 7800...  Training loss: 1.3376...  0.0418 sec/batch
# Epoch: 2/20...  Training Step: 7850...  Training loss: 1.3204...  0.0412 sec/batch
# Epoch: 2/20...  Training Step: 7900...  Training loss: 1.4484...  0.0421 sec/batch
# Epoch: 3/20...  Training Step: 7950...  Training loss: 1.3535...  0.0412 sec/batch
# Epoch: 3/20...  Training Step: 8000...  Training loss: 1.3107...  0.0419 sec/batch
# Epoch: 3/20...  Training Step: 8050...  Training loss: 1.3474...  0.0419 sec/batch
# Epoch: 3/20...  Training Step: 8100...  Training loss: 1.5029...  0.0417 sec/batch
# Epoch: 3/20...  Training Step: 8150...  Training loss: 1.3025...  0.0439 sec/batch
# Epoch: 3/20...  Training Step: 8200...  Training loss: 1.1957...  0.0415 sec/batch
# Epoch: 3/20...  Training Step: 8250...  Training loss: 1.4504...  0.0410 sec/batch
# Epoch: 3/20...  Training Step: 8300...  Training loss: 1.3791...  0.0447 sec/batch
# Epoch: 3/20...  Training Step: 8350...  Training loss: 1.3318...  0.0446 sec/batch
# Epoch: 3/20...  Training Step: 8400...  Training loss: 1.4368...  0.0445 sec/batch
# Epoch: 3/20...  Training Step: 8450...  Training loss: 1.4267...  0.0419 sec/batch
# Epoch: 3/20...  Training Step: 8500...  Training loss: 1.3456...  0.0445 sec/batch
# Epoch: 3/20...  Training Step: 8550...  Training loss: 1.3076...  0.0418 sec/batch
# Epoch: 3/20...  Training Step: 8600...  Training loss: 1.2928...  0.0447 sec/batch
# Epoch: 3/20...  Training Step: 8650...  Training loss: 1.3826...  0.0418 sec/batch
# Epoch: 3/20...  Training Step: 8700...  Training loss: 1.1250...  0.0416 sec/batch
# Epoch: 3/20...  Training Step: 8750...  Training loss: 1.2794...  0.0416 sec/batch
# Epoch: 3/20...  Training Step: 8800...  Training loss: 1.5384...  0.0437 sec/batch
# Epoch: 3/20...  Training Step: 8850...  Training loss: 1.3688...  0.0415 sec/batch
# Epoch: 3/20...  Training Step: 8900...  Training loss: 1.3436...  0.0420 sec/batch
# Epoch: 3/20...  Training Step: 8950...  Training loss: 1.4351...  0.0444 sec/batch
# Epoch: 3/20...  Training Step: 9000...  Training loss: 1.2392...  0.0444 sec/batch
# Epoch: 3/20...  Training Step: 9050...  Training loss: 1.2455...  0.0423 sec/batch
# Epoch: 3/20...  Training Step: 9100...  Training loss: 1.2587...  0.0414 sec/batch
# Epoch: 3/20...  Training Step: 9150...  Training loss: 1.3046...  0.0416 sec/batch
# Epoch: 3/20...  Training Step: 9200...  Training loss: 1.3285...  0.0418 sec/batch
# Epoch: 3/20...  Training Step: 9250...  Training loss: 1.3385...  0.0431 sec/batch
# Epoch: 3/20...  Training Step: 9300...  Training loss: 1.1702...  0.0438 sec/batch
# Epoch: 3/20...  Training Step: 9350...  Training loss: 1.3051...  0.0445 sec/batch
# Epoch: 3/20...  Training Step: 9400...  Training loss: 1.3763...  0.0413 sec/batch
# Epoch: 3/20...  Training Step: 9450...  Training loss: 1.2383...  0.0424 sec/batch
# Epoch: 3/20...  Training Step: 9500...  Training loss: 1.3999...  0.0415 sec/batch
# Epoch: 3/20...  Training Step: 9550...  Training loss: 1.3710...  0.0439 sec/batch
# Epoch: 3/20...  Training Step: 9600...  Training loss: 1.1564...  0.0414 sec/batch
# Epoch: 3/20...  Training Step: 9650...  Training loss: 1.2508...  0.0416 sec/batch
# Epoch: 3/20...  Training Step: 9700...  Training loss: 1.2667...  0.0423 sec/batch
# Epoch: 3/20...  Training Step: 9750...  Training loss: 1.1896...  0.0445 sec/batch
# Epoch: 3/20...  Training Step: 9800...  Training loss: 1.3198...  0.0409 sec/batch
# Epoch: 3/20...  Training Step: 9850...  Training loss: 1.2336...  0.0418 sec/batch
# Epoch: 3/20...  Training Step: 9900...  Training loss: 1.3506...  0.0438 sec/batch
# Epoch: 3/20...  Training Step: 9950...  Training loss: 1.2742...  0.0423 sec/batch
# Epoch: 3/20...  Training Step: 10000...  Training loss: 1.2421...  0.0418 sec/batch
# Epoch: 3/20...  Training Step: 10050...  Training loss: 1.3213...  0.0426 sec/batch
# Epoch: 3/20...  Training Step: 10100...  Training loss: 1.3049...  0.0415 sec/batch
# Epoch: 3/20...  Training Step: 10150...  Training loss: 1.3883...  0.0447 sec/batch
# Epoch: 3/20...  Training Step: 10200...  Training loss: 1.4327...  0.0417 sec/batch
# Epoch: 3/20...  Training Step: 10250...  Training loss: 1.2717...  0.0437 sec/batch
# Epoch: 3/20...  Training Step: 10300...  Training loss: 1.4253...  0.0419 sec/batch
# Epoch: 3/20...  Training Step: 10350...  Training loss: 1.2595...  0.0420 sec/batch
# Epoch: 3/20...  Training Step: 10400...  Training loss: 1.3969...  0.0425 sec/batch
# Epoch: 3/20...  Training Step: 10450...  Training loss: 1.2099...  0.0425 sec/batch
# Epoch: 3/20...  Training Step: 10500...  Training loss: 1.1299...  0.0418 sec/batch
# Epoch: 3/20...  Training Step: 10550...  Training loss: 1.3796...  0.0415 sec/batch
# Epoch: 3/20...  Training Step: 10600...  Training loss: 1.3104...  0.0422 sec/batch
# Epoch: 3/20...  Training Step: 10650...  Training loss: 1.2722...  0.0417 sec/batch
# Epoch: 3/20...  Training Step: 10700...  Training loss: 1.3322...  0.0425 sec/batch
# Epoch: 3/20...  Training Step: 10750...  Training loss: 1.3960...  0.0425 sec/batch
# Epoch: 3/20...  Training Step: 10800...  Training loss: 1.2316...  0.0438 sec/batch
# Epoch: 3/20...  Training Step: 10850...  Training loss: 1.2951...  0.0412 sec/batch
# Epoch: 3/20...  Training Step: 10900...  Training loss: 1.3263...  0.0426 sec/batch
# Epoch: 3/20...  Training Step: 10950...  Training loss: 1.4006...  0.0431 sec/batch
# Epoch: 3/20...  Training Step: 11000...  Training loss: 1.2995...  0.0421 sec/batch
# Epoch: 3/20...  Training Step: 11050...  Training loss: 1.2420...  0.0421 sec/batch
# Epoch: 3/20...  Training Step: 11100...  Training loss: 1.2344...  0.0445 sec/batch
# Epoch: 3/20...  Training Step: 11150...  Training loss: 1.1790...  0.0441 sec/batch
# Epoch: 3/20...  Training Step: 11200...  Training loss: 1.2537...  0.0420 sec/batch
# Epoch: 3/20...  Training Step: 11250...  Training loss: 1.4193...  0.0419 sec/batch
# Epoch: 3/20...  Training Step: 11300...  Training loss: 1.1978...  0.0446 sec/batch
# Epoch: 3/20...  Training Step: 11350...  Training loss: 1.3102...  0.0416 sec/batch
# Epoch: 3/20...  Training Step: 11400...  Training loss: 1.2787...  0.0417 sec/batch
# Epoch: 3/20...  Training Step: 11450...  Training loss: 1.3054...  0.0449 sec/batch
# Epoch: 3/20...  Training Step: 11500...  Training loss: 1.1824...  0.0423 sec/batch
# Epoch: 3/20...  Training Step: 11550...  Training loss: 1.3737...  0.0438 sec/batch
# Epoch: 3/20...  Training Step: 11600...  Training loss: 1.3222...  0.0415 sec/batch
# Epoch: 3/20...  Training Step: 11650...  Training loss: 1.2653...  0.0422 sec/batch
# Epoch: 3/20...  Training Step: 11700...  Training loss: 1.1878...  0.0429 sec/batch
# Epoch: 3/20...  Training Step: 11750...  Training loss: 1.2269...  0.0443 sec/batch
# Epoch: 3/20...  Training Step: 11800...  Training loss: 1.3958...  0.0414 sec/batch
# Epoch: 3/20...  Training Step: 11850...  Training loss: 1.6229...  0.0420 sec/batch
# Epoch: 3/20...  Training Step: 11900...  Training loss: 1.3178...  0.0422 sec/batch
# Epoch: 4/20...  Training Step: 11950...  Training loss: 1.3788...  0.0444 sec/batch
# Epoch: 4/20...  Training Step: 12000...  Training loss: 1.3168...  0.0425 sec/batch
# Epoch: 4/20...  Training Step: 12050...  Training loss: 1.2702...  0.0446 sec/batch
# Epoch: 4/20...  Training Step: 12100...  Training loss: 1.2801...  0.0425 sec/batch
# Epoch: 4/20...  Training Step: 12150...  Training loss: 1.4116...  0.0426 sec/batch
# Epoch: 4/20...  Training Step: 12200...  Training loss: 1.2890...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 12250...  Training loss: 1.3525...  0.0424 sec/batch
# Epoch: 4/20...  Training Step: 12300...  Training loss: 1.2568...  0.0429 sec/batch
# Epoch: 4/20...  Training Step: 12350...  Training loss: 1.3995...  0.0439 sec/batch
# Epoch: 4/20...  Training Step: 12400...  Training loss: 1.3253...  0.0417 sec/batch
# Epoch: 4/20...  Training Step: 12450...  Training loss: 1.1421...  0.0449 sec/batch
# Epoch: 4/20...  Training Step: 12500...  Training loss: 1.4587...  0.0413 sec/batch
# Epoch: 4/20...  Training Step: 12550...  Training loss: 1.1726...  0.0441 sec/batch
# Epoch: 4/20...  Training Step: 12600...  Training loss: 1.2104...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 12650...  Training loss: 1.2313...  0.0421 sec/batch
# Epoch: 4/20...  Training Step: 12700...  Training loss: 1.3000...  0.0444 sec/batch
# Epoch: 4/20...  Training Step: 12750...  Training loss: 1.2975...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 12800...  Training loss: 1.2908...  0.0416 sec/batch
# Epoch: 4/20...  Training Step: 12850...  Training loss: 1.1584...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 12900...  Training loss: 1.1717...  0.0443 sec/batch
# Epoch: 4/20...  Training Step: 12950...  Training loss: 1.2703...  0.0434 sec/batch
# Epoch: 4/20...  Training Step: 13000...  Training loss: 1.4212...  0.0428 sec/batch
# Epoch: 4/20...  Training Step: 13050...  Training loss: 1.3015...  0.0417 sec/batch
# Epoch: 4/20...  Training Step: 13100...  Training loss: 1.1878...  0.0445 sec/batch
# Epoch: 4/20...  Training Step: 13150...  Training loss: 1.2083...  0.0449 sec/batch
# Epoch: 4/20...  Training Step: 13200...  Training loss: 1.4638...  0.0448 sec/batch
# Epoch: 4/20...  Training Step: 13250...  Training loss: 1.2912...  0.0420 sec/batch
# Epoch: 4/20...  Training Step: 13300...  Training loss: 1.2544...  0.0425 sec/batch
# Epoch: 4/20...  Training Step: 13350...  Training loss: 1.2241...  0.0426 sec/batch
# Epoch: 4/20...  Training Step: 13400...  Training loss: 1.3597...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 13450...  Training loss: 1.3505...  0.0440 sec/batch
# Epoch: 4/20...  Training Step: 13500...  Training loss: 1.3019...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 13550...  Training loss: 1.3414...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 13600...  Training loss: 1.3000...  0.0456 sec/batch
# Epoch: 4/20...  Training Step: 13650...  Training loss: 1.2629...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 13700...  Training loss: 1.2805...  0.0424 sec/batch
# Epoch: 4/20...  Training Step: 13750...  Training loss: 1.2864...  0.0426 sec/batch
# Epoch: 4/20...  Training Step: 13800...  Training loss: 1.3105...  0.0422 sec/batch
# Epoch: 4/20...  Training Step: 13850...  Training loss: 1.6397...  0.0449 sec/batch
# Epoch: 4/20...  Training Step: 13900...  Training loss: 1.3592...  0.0417 sec/batch
# Epoch: 4/20...  Training Step: 13950...  Training loss: 1.3060...  0.0439 sec/batch
# Epoch: 4/20...  Training Step: 14000...  Training loss: 1.2560...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 14050...  Training loss: 1.2729...  0.0422 sec/batch
# Epoch: 4/20...  Training Step: 14100...  Training loss: 1.2348...  0.0446 sec/batch
# Epoch: 4/20...  Training Step: 14150...  Training loss: 1.4894...  0.0446 sec/batch
# Epoch: 4/20...  Training Step: 14200...  Training loss: 1.2989...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 14250...  Training loss: 1.4338...  0.0416 sec/batch
# Epoch: 4/20...  Training Step: 14300...  Training loss: 1.3764...  0.0424 sec/batch
# Epoch: 4/20...  Training Step: 14350...  Training loss: 1.2063...  0.0453 sec/batch
# Epoch: 4/20...  Training Step: 14400...  Training loss: 1.3008...  0.0444 sec/batch
# Epoch: 4/20...  Training Step: 14450...  Training loss: 1.3278...  0.0448 sec/batch
# Epoch: 4/20...  Training Step: 14500...  Training loss: 1.3084...  0.0414 sec/batch
# Epoch: 4/20...  Training Step: 14550...  Training loss: 1.2310...  0.0451 sec/batch
# Epoch: 4/20...  Training Step: 14600...  Training loss: 1.3149...  0.0427 sec/batch
# Epoch: 4/20...  Training Step: 14650...  Training loss: 1.2393...  0.0416 sec/batch
# Epoch: 4/20...  Training Step: 14700...  Training loss: 1.2196...  0.0421 sec/batch
# Epoch: 4/20...  Training Step: 14750...  Training loss: 1.2844...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 14800...  Training loss: 1.1806...  0.0431 sec/batch
# Epoch: 4/20...  Training Step: 14850...  Training loss: 1.3426...  0.0416 sec/batch
# Epoch: 4/20...  Training Step: 14900...  Training loss: 1.2903...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 14950...  Training loss: 1.3228...  0.0429 sec/batch
# Epoch: 4/20...  Training Step: 15000...  Training loss: 1.2425...  0.0437 sec/batch
# Epoch: 4/20...  Training Step: 15050...  Training loss: 1.3512...  0.0438 sec/batch
# Epoch: 4/20...  Training Step: 15100...  Training loss: 1.2212...  0.0443 sec/batch
# Epoch: 4/20...  Training Step: 15150...  Training loss: 1.2697...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 15200...  Training loss: 1.3403...  0.0420 sec/batch
# Epoch: 4/20...  Training Step: 15250...  Training loss: 1.2688...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 15300...  Training loss: 1.2116...  0.0423 sec/batch
# Epoch: 4/20...  Training Step: 15350...  Training loss: 1.3046...  0.0441 sec/batch
# Epoch: 4/20...  Training Step: 15400...  Training loss: 1.3858...  0.0441 sec/batch
# Epoch: 4/20...  Training Step: 15450...  Training loss: 1.2627...  0.0450 sec/batch
# Epoch: 4/20...  Training Step: 15500...  Training loss: 1.1900...  0.0443 sec/batch
# Epoch: 4/20...  Training Step: 15550...  Training loss: 1.2595...  0.0451 sec/batch
# Epoch: 4/20...  Training Step: 15600...  Training loss: 1.2784...  0.0450 sec/batch
# Epoch: 4/20...  Training Step: 15650...  Training loss: 1.2957...  0.0445 sec/batch
# Epoch: 4/20...  Training Step: 15700...  Training loss: 1.2065...  0.0439 sec/batch
# Epoch: 4/20...  Training Step: 15750...  Training loss: 1.3840...  0.0425 sec/batch
# Epoch: 4/20...  Training Step: 15800...  Training loss: 1.2841...  0.0419 sec/batch
# Epoch: 4/20...  Training Step: 15850...  Training loss: 1.3174...  0.0433 sec/batch
# Epoch: 5/20...  Training Step: 15900...  Training loss: 1.4411...  0.0445 sec/batch
# Epoch: 5/20...  Training Step: 15950...  Training loss: 1.3011...  0.0410 sec/batch
# Epoch: 5/20...  Training Step: 16000...  Training loss: 1.2446...  0.0443 sec/batch
# Epoch: 5/20...  Training Step: 16050...  Training loss: 1.3172...  0.0420 sec/batch
# Epoch: 5/20...  Training Step: 16100...  Training loss: 1.2868...  0.0426 sec/batch
# Epoch: 5/20...  Training Step: 16150...  Training loss: 1.3595...  0.0415 sec/batch
# Epoch: 5/20...  Training Step: 16200...  Training loss: 1.3856...  0.0428 sec/batch
# Epoch: 5/20...  Training Step: 16250...  Training loss: 1.3664...  0.0430 sec/batch
# Epoch: 5/20...  Training Step: 16300...  Training loss: 1.3817...  0.0418 sec/batch
# Epoch: 5/20...  Training Step: 16350...  Training loss: 1.2940...  0.0422 sec/batch
# Epoch: 5/20...  Training Step: 16400...  Training loss: 1.1931...  0.0447 sec/batch
# Epoch: 5/20...  Training Step: 16450...  Training loss: 1.3586...  0.0442 sec/batch
# Epoch: 5/20...  Training Step: 16500...  Training loss: 1.1843...  0.0445 sec/batch
# Epoch: 5/20...  Training Step: 16550...  Training loss: 1.3052...  0.0424 sec/batch
# Epoch: 5/20...  Training Step: 16600...  Training loss: 1.2985...  0.0440 sec/batch
# Epoch: 5/20...  Training Step: 16650...  Training loss: 1.2268...  0.0450 sec/batch
# Epoch: 5/20...  Training Step: 16700...  Training loss: 1.2704...  0.0427 sec/batch
# Epoch: 5/20...  Training Step: 16750...  Training loss: 1.2493...  0.0451 sec/batch
# Epoch: 5/20...  Training Step: 16800...  Training loss: 1.2353...  0.0443 sec/batch
# Epoch: 5/20...  Training Step: 16850...  Training loss: 1.2009...  0.0426 sec/batch
# Epoch: 5/20...  Training Step: 16900...  Training loss: 1.1229...  0.0445 sec/batch
# Epoch: 5/20...  Training Step: 16950...  Training loss: 1.1567...  0.0415 sec/batch
# Epoch: 5/20...  Training Step: 17000...  Training loss: 1.1610...  0.0428 sec/batch
# Epoch: 5/20...  Training Step: 17050...  Training loss: 1.2137...  0.0444 sec/batch
# Epoch: 5/20...  Training Step: 17100...  Training loss: 1.1782...  0.0440 sec/batch
# Epoch: 5/20...  Training Step: 17150...  Training loss: 1.3240...  0.0444 sec/batch
# Epoch: 5/20...  Training Step: 17200...  Training loss: 1.3456...  0.0418 sec/batch
# Epoch: 5/20...  Training Step: 17250...  Training loss: 1.3024...  0.0432 sec/batch
# Epoch: 5/20...  Training Step: 17300...  Training loss: 1.3323...  0.0449 sec/batch
# Epoch: 5/20...  Training Step: 17350...  Training loss: 1.2667...  0.0442 sec/batch
# Epoch: 5/20...  Training Step: 17400...  Training loss: 1.2309...  0.0447 sec/batch
# Epoch: 5/20...  Training Step: 17450...  Training loss: 1.2680...  0.0442 sec/batch
# Epoch: 5/20...  Training Step: 17500...  Training loss: 1.3836...  0.0424 sec/batch
# Epoch: 5/20...  Training Step: 17550...  Training loss: 1.3218...  0.0426 sec/batch
# Epoch: 5/20...  Training Step: 17600...  Training loss: 1.2253...  0.0426 sec/batch
# Epoch: 5/20...  Training Step: 17650...  Training loss: 1.3605...  0.0429 sec/batch
# Epoch: 5/20...  Training Step: 17700...  Training loss: 1.2746...  0.0420 sec/batch
# Epoch: 5/20...  Training Step: 17750...  Training loss: 1.0917...  0.0444 sec/batch
# Epoch: 5/20...  Training Step: 17800...  Training loss: 1.2961...  0.0436 sec/batch
# Epoch: 5/20...  Training Step: 17850...  Training loss: 1.2991...  0.0441 sec/batch
# Epoch: 5/20...  Training Step: 17900...  Training loss: 1.1845...  0.0447 sec/batch
# Epoch: 5/20...  Training Step: 17950...  Training loss: 1.2280...  0.0427 sec/batch
# Epoch: 5/20...  Training Step: 18000...  Training loss: 1.0490...  0.0444 sec/batch
# Epoch: 5/20...  Training Step: 18050...  Training loss: 1.2289...  0.0424 sec/batch
# Epoch: 5/20...  Training Step: 18100...  Training loss: 1.2424...  0.0447 sec/batch
# Epoch: 5/20...  Training Step: 18150...  Training loss: 1.1309...  0.0406 sec/batch
# Epoch: 5/20...  Training Step: 18200...  Training loss: 1.2192...  0.0433 sec/batch
# Epoch: 5/20...  Training Step: 18250...  Training loss: 1.1852...  0.0427 sec/batch
# Epoch: 5/20...  Training Step: 18300...  Training loss: 1.3743...  0.0447 sec/batch
# Epoch: 5/20...  Training Step: 18350...  Training loss: 1.2763...  0.0426 sec/batch
# Epoch: 5/20...  Training Step: 18400...  Training loss: 1.3484...  0.0422 sec/batch
# Epoch: 5/20...  Training Step: 18450...  Training loss: 1.1546...  0.0444 sec/batch
# Epoch: 5/20...  Training Step: 18500...  Training loss: 1.1272...  0.0418 sec/batch
# Epoch: 5/20...  Training Step: 18550...  Training loss: 1.3072...  0.0424 sec/batch
# Epoch: 5/20...  Training Step: 18600...  Training loss: 1.1750...  0.0415 sec/batch
# Epoch: 5/20...  Training Step: 18650...  Training loss: 1.3228...  0.0411 sec/batch
# Epoch: 5/20...  Training Step: 18700...  Training loss: 1.3983...  0.0440 sec/batch
# Epoch: 5/20...  Training Step: 18750...  Training loss: 1.1968...  0.0417 sec/batch
# Epoch: 5/20...  Training Step: 18800...  Training loss: 1.3972...  0.0420 sec/batch
# Epoch: 5/20...  Training Step: 18850...  Training loss: 1.1922...  0.0418 sec/batch
# Epoch: 5/20...  Training Step: 18900...  Training loss: 1.3833...  0.0422 sec/batch
# Epoch: 5/20...  Training Step: 18950...  Training loss: 1.2204...  0.0413 sec/batch
# Epoch: 5/20...  Training Step: 19000...  Training loss: 1.1862...  0.0418 sec/batch
# Epoch: 5/20...  Training Step: 19050...  Training loss: 1.2993...  0.0420 sec/batch
# Epoch: 5/20...  Training Step: 19100...  Training loss: 1.2644...  0.0411 sec/batch
# Epoch: 5/20...  Training Step: 19150...  Training loss: 1.3224...  0.0421 sec/batch
# Epoch: 5/20...  Training Step: 19200...  Training loss: 1.2049...  0.0421 sec/batch
# Epoch: 5/20...  Training Step: 19250...  Training loss: 1.1638...  0.0417 sec/batch
# Epoch: 5/20...  Training Step: 19300...  Training loss: 1.4426...  0.0412 sec/batch
# Epoch: 5/20...  Training Step: 19350...  Training loss: 1.2830...  0.0450 sec/batch
# Epoch: 5/20...  Training Step: 19400...  Training loss: 1.2592...  0.0421 sec/batch
# Epoch: 5/20...  Training Step: 19450...  Training loss: 1.0674...  0.0442 sec/batch
# Epoch: 5/20...  Training Step: 19500...  Training loss: 1.1689...  0.0415 sec/batch
# Epoch: 5/20...  Training Step: 19550...  Training loss: 1.2932...  0.0417 sec/batch
# Epoch: 5/20...  Training Step: 19600...  Training loss: 1.2475...  0.0421 sec/batch
# Epoch: 5/20...  Training Step: 19650...  Training loss: 1.2190...  0.0422 sec/batch
# Epoch: 5/20...  Training Step: 19700...  Training loss: 1.4982...  0.0412 sec/batch
# Epoch: 5/20...  Training Step: 19750...  Training loss: 1.3742...  0.0418 sec/batch
# Epoch: 5/20...  Training Step: 19800...  Training loss: 1.5726...  0.0419 sec/batch
# Epoch: 5/20...  Training Step: 19850...  Training loss: 1.4721...  0.0447 sec/batch
# Epoch: 6/20...  Training Step: 19900...  Training loss: 1.3971...  0.0441 sec/batch
# Epoch: 6/20...  Training Step: 19950...  Training loss: 1.2727...  0.0425 sec/batch
# Epoch: 6/20...  Training Step: 20000...  Training loss: 1.1103...  0.0416 sec/batch
# Epoch: 6/20...  Training Step: 20050...  Training loss: 1.2814...  0.0442 sec/batch
# Epoch: 6/20...  Training Step: 20100...  Training loss: 1.3091...  0.0445 sec/batch
# Epoch: 6/20...  Training Step: 20150...  Training loss: 1.0864...  0.0437 sec/batch
# Epoch: 6/20...  Training Step: 20200...  Training loss: 1.2914...  0.0420 sec/batch
# Epoch: 6/20...  Training Step: 20250...  Training loss: 1.3114...  0.0420 sec/batch
# Epoch: 6/20...  Training Step: 20300...  Training loss: 1.3817...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 20350...  Training loss: 1.3509...  0.0424 sec/batch
# Epoch: 6/20...  Training Step: 20400...  Training loss: 1.1546...  0.0445 sec/batch
# Epoch: 6/20...  Training Step: 20450...  Training loss: 1.1909...  0.0423 sec/batch
# Epoch: 6/20...  Training Step: 20500...  Training loss: 1.1145...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 20550...  Training loss: 1.1785...  0.0446 sec/batch
# Epoch: 6/20...  Training Step: 20600...  Training loss: 1.2089...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 20650...  Training loss: 1.2495...  0.0445 sec/batch
# Epoch: 6/20...  Training Step: 20700...  Training loss: 1.3627...  0.0432 sec/batch
# Epoch: 6/20...  Training Step: 20750...  Training loss: 1.3303...  0.0450 sec/batch
# Epoch: 6/20...  Training Step: 20800...  Training loss: 1.2903...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 20850...  Training loss: 1.2757...  0.0430 sec/batch
# Epoch: 6/20...  Training Step: 20900...  Training loss: 1.2482...  0.0451 sec/batch
# Epoch: 6/20...  Training Step: 20950...  Training loss: 1.2613...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 21000...  Training loss: 1.2673...  0.0444 sec/batch
# Epoch: 6/20...  Training Step: 21050...  Training loss: 1.1525...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 21100...  Training loss: 1.1364...  0.0444 sec/batch
# Epoch: 6/20...  Training Step: 21150...  Training loss: 1.2112...  0.0423 sec/batch
# Epoch: 6/20...  Training Step: 21200...  Training loss: 1.1631...  0.0419 sec/batch
# Epoch: 6/20...  Training Step: 21250...  Training loss: 1.4282...  0.0436 sec/batch
# Epoch: 6/20...  Training Step: 21300...  Training loss: 1.3226...  0.0426 sec/batch
# Epoch: 6/20...  Training Step: 21350...  Training loss: 1.2878...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 21400...  Training loss: 1.2340...  0.0440 sec/batch
# Epoch: 6/20...  Training Step: 21450...  Training loss: 1.3222...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 21500...  Training loss: 1.1904...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 21550...  Training loss: 1.2723...  0.0444 sec/batch
# Epoch: 6/20...  Training Step: 21600...  Training loss: 1.3014...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 21650...  Training loss: 1.3127...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 21700...  Training loss: 1.3475...  0.0442 sec/batch
# Epoch: 6/20...  Training Step: 21750...  Training loss: 1.0273...  0.0441 sec/batch
# Epoch: 6/20...  Training Step: 21800...  Training loss: 1.1888...  0.0451 sec/batch
# Epoch: 6/20...  Training Step: 21850...  Training loss: 1.3047...  0.0413 sec/batch
# Epoch: 6/20...  Training Step: 21900...  Training loss: 1.3261...  0.0441 sec/batch
# Epoch: 6/20...  Training Step: 21950...  Training loss: 1.2354...  0.0441 sec/batch
# Epoch: 6/20...  Training Step: 22000...  Training loss: 1.2913...  0.0423 sec/batch
# Epoch: 6/20...  Training Step: 22050...  Training loss: 1.3028...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 22100...  Training loss: 1.2946...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 22150...  Training loss: 1.1740...  0.0420 sec/batch
# Epoch: 6/20...  Training Step: 22200...  Training loss: 1.3516...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 22250...  Training loss: 1.3535...  0.0439 sec/batch
# Epoch: 6/20...  Training Step: 22300...  Training loss: 1.3274...  0.0448 sec/batch
# Epoch: 6/20...  Training Step: 22350...  Training loss: 1.2706...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 22400...  Training loss: 1.3052...  0.0454 sec/batch
# Epoch: 6/20...  Training Step: 22450...  Training loss: 1.2230...  0.0427 sec/batch
# Epoch: 6/20...  Training Step: 22500...  Training loss: 1.3000...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 22550...  Training loss: 1.3460...  0.0449 sec/batch
# Epoch: 6/20...  Training Step: 22600...  Training loss: 1.2115...  0.0446 sec/batch
# Epoch: 6/20...  Training Step: 22650...  Training loss: 1.0365...  0.0423 sec/batch
# Epoch: 6/20...  Training Step: 22700...  Training loss: 1.3995...  0.0420 sec/batch
# Epoch: 6/20...  Training Step: 22750...  Training loss: 1.1236...  0.0444 sec/batch
# Epoch: 6/20...  Training Step: 22800...  Training loss: 1.1101...  0.0441 sec/batch
# Epoch: 6/20...  Training Step: 22850...  Training loss: 1.2498...  0.0447 sec/batch
# Epoch: 6/20...  Training Step: 22900...  Training loss: 1.3855...  0.0431 sec/batch
# Epoch: 6/20...  Training Step: 22950...  Training loss: 1.2610...  0.0424 sec/batch
# Epoch: 6/20...  Training Step: 23000...  Training loss: 1.1609...  0.0423 sec/batch
# Epoch: 6/20...  Training Step: 23050...  Training loss: 1.4019...  0.0416 sec/batch
# Epoch: 6/20...  Training Step: 23100...  Training loss: 1.2990...  0.0430 sec/batch
# Epoch: 6/20...  Training Step: 23150...  Training loss: 1.2646...  0.0414 sec/batch
# Epoch: 6/20...  Training Step: 23200...  Training loss: 1.1833...  0.0427 sec/batch
# Epoch: 6/20...  Training Step: 23250...  Training loss: 1.3028...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 23300...  Training loss: 1.1871...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 23350...  Training loss: 1.2052...  0.0436 sec/batch
# Epoch: 6/20...  Training Step: 23400...  Training loss: 1.3085...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 23450...  Training loss: 1.2835...  0.0418 sec/batch
# Epoch: 6/20...  Training Step: 23500...  Training loss: 1.4508...  0.0416 sec/batch
# Epoch: 6/20...  Training Step: 23550...  Training loss: 1.1747...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 23600...  Training loss: 1.3068...  0.0414 sec/batch
# Epoch: 6/20...  Training Step: 23650...  Training loss: 1.2007...  0.0417 sec/batch
# Epoch: 6/20...  Training Step: 23700...  Training loss: 1.3377...  0.0422 sec/batch
# Epoch: 6/20...  Training Step: 23750...  Training loss: 1.5041...  0.0449 sec/batch
# Epoch: 6/20...  Training Step: 23800...  Training loss: 1.2301...  0.0421 sec/batch
# Epoch: 7/20...  Training Step: 23850...  Training loss: 1.2654...  0.0427 sec/batch
# Epoch: 7/20...  Training Step: 23900...  Training loss: 1.2407...  0.0449 sec/batch
# Epoch: 7/20...  Training Step: 23950...  Training loss: 1.2398...  0.0420 sec/batch
# Epoch: 7/20...  Training Step: 24000...  Training loss: 1.1993...  0.0434 sec/batch
# Epoch: 7/20...  Training Step: 24050...  Training loss: 1.2579...  0.0424 sec/batch
# Epoch: 7/20...  Training Step: 24100...  Training loss: 1.3450...  0.0422 sec/batch
# Epoch: 7/20...  Training Step: 24150...  Training loss: 1.3417...  0.0444 sec/batch
# Epoch: 7/20...  Training Step: 24200...  Training loss: 1.3336...  0.0439 sec/batch
# Epoch: 7/20...  Training Step: 24250...  Training loss: 1.2743...  0.0421 sec/batch
# Epoch: 7/20...  Training Step: 24300...  Training loss: 1.4080...  0.0424 sec/batch
# Epoch: 7/20...  Training Step: 24350...  Training loss: 1.2792...  0.0448 sec/batch
# Epoch: 7/20...  Training Step: 24400...  Training loss: 1.4613...  0.0421 sec/batch
# Epoch: 7/20...  Training Step: 24450...  Training loss: 1.3261...  0.0441 sec/batch
# Epoch: 7/20...  Training Step: 24500...  Training loss: 1.3811...  0.0440 sec/batch
# Epoch: 7/20...  Training Step: 24550...  Training loss: 1.1837...  0.0440 sec/batch
# Epoch: 7/20...  Training Step: 24600...  Training loss: 1.4480...  0.0419 sec/batch
# Epoch: 7/20...  Training Step: 24650...  Training loss: 1.1857...  0.0418 sec/batch
# Epoch: 7/20...  Training Step: 24700...  Training loss: 1.1645...  0.0446 sec/batch
# Epoch: 7/20...  Training Step: 24750...  Training loss: 1.2569...  0.0428 sec/batch
# Epoch: 7/20...  Training Step: 24800...  Training loss: 1.1930...  0.0447 sec/batch
# Epoch: 7/20...  Training Step: 24850...  Training loss: 1.2919...  0.0428 sec/batch
# Epoch: 7/20...  Training Step: 24900...  Training loss: 1.1078...  0.0420 sec/batch
# Epoch: 7/20...  Training Step: 24950...  Training loss: 1.1422...  0.0426 sec/batch
# Epoch: 7/20...  Training Step: 25000...  Training loss: 1.2759...  0.0419 sec/batch
# Epoch: 7/20...  Training Step: 25050...  Training loss: 1.2868...  0.0420 sec/batch
# Epoch: 7/20...  Training Step: 25100...  Training loss: 1.1684...  0.0429 sec/batch
# Epoch: 7/20...  Training Step: 25150...  Training loss: 1.2843...  0.0444 sec/batch
# Epoch: 7/20...  Training Step: 25200...  Training loss: 1.2321...  0.0432 sec/batch
# Epoch: 7/20...  Training Step: 25250...  Training loss: 1.3901...  0.0419 sec/batch
# Epoch: 7/20...  Training Step: 25300...  Training loss: 1.2885...  0.0428 sec/batch
# Epoch: 7/20...  Training Step: 25350...  Training loss: 1.3003...  0.0420 sec/batch
# Epoch: 7/20...  Training Step: 25400...  Training loss: 1.2709...  0.0416 sec/batch
# Epoch: 7/20...  Training Step: 25450...  Training loss: 1.3806...  0.0425 sec/batch
# Epoch: 7/20...  Training Step: 25500...  Training loss: 1.2257...  0.0414 sec/batch
# Epoch: 7/20...  Training Step: 25550...  Training loss: 1.1652...  0.0419 sec/batch
# Epoch: 7/20...  Training Step: 25600...  Training loss: 1.2106...  0.0413 sec/batch
# Epoch: 7/20...  Training Step: 25650...  Training loss: 1.3215...  0.0420 sec/batch
# Epoch: 7/20...  Training Step: 25700...  Training loss: 1.3367...  0.0448 sec/batch
# Epoch: 7/20...  Training Step: 25750...  Training loss: 1.2035...  0.0449 sec/batch
# Epoch: 7/20...  Training Step: 25800...  Training loss: 1.3010...  0.0421 sec/batch
# Epoch: 7/20...  Training Step: 25850...  Training loss: 1.1904...  0.0423 sec/batch
# Epoch: 7/20...  Training Step: 25900...  Training loss: 1.2002...  0.0443 sec/batch
# Epoch: 7/20...  Training Step: 25950...  Training loss: 1.3398...  0.0416 sec/batch
# Epoch: 7/20...  Training Step: 26000...  Training loss: 1.2887...  0.0450 sec/batch
# Epoch: 7/20...  Training Step: 26050...  Training loss: 1.3244...  0.0423 sec/batch
# Epoch: 7/20...  Training Step: 26100...  Training loss: 1.2844...  0.0413 sec/batch
# Epoch: 7/20...  Training Step: 26150...  Training loss: 1.1949...  0.0447 sec/batch
# Epoch: 7/20...  Training Step: 26200...  Training loss: 1.3212...  0.0428 sec/batch
# Epoch: 7/20...  Training Step: 26250...  Training loss: 1.1645...  0.0412 sec/batch
# Epoch: 7/20...  Training Step: 26300...  Training loss: 1.2246...  0.0449 sec/batch
# Epoch: 7/20...  Training Step: 26350...  Training loss: 1.1261...  0.0414 sec/batch
# Epoch: 7/20...  Training Step: 26400...  Training loss: 1.3013...  0.0419 sec/batch
# Epoch: 7/20...  Training Step: 26450...  Training loss: 1.3807...  0.0448 sec/batch
# Epoch: 7/20...  Training Step: 26500...  Training loss: 1.2176...  0.0416 sec/batch
# Epoch: 7/20...  Training Step: 26550...  Training loss: 1.2503...  0.0446 sec/batch
# Epoch: 7/20...  Training Step: 26600...  Training loss: 1.2398...  0.0426 sec/batch
# Epoch: 7/20...  Training Step: 26650...  Training loss: 1.2916...  0.0424 sec/batch
# Epoch: 7/20...  Training Step: 26700...  Training loss: 1.2939...  0.0419 sec/batch
# Epoch: 7/20...  Training Step: 26750...  Training loss: 1.1631...  0.0418 sec/batch
# Epoch: 7/20...  Training Step: 26800...  Training loss: 1.4965...  0.0445 sec/batch
# Epoch: 7/20...  Training Step: 26850...  Training loss: 1.1985...  0.0423 sec/batch
# Epoch: 7/20...  Training Step: 26900...  Training loss: 1.2167...  0.0442 sec/batch
# Epoch: 7/20...  Training Step: 26950...  Training loss: 1.1652...  0.0416 sec/batch
# Epoch: 7/20...  Training Step: 27000...  Training loss: 1.1638...  0.0420 sec/batch
# Epoch: 7/20...  Training Step: 27050...  Training loss: 1.3281...  0.0421 sec/batch
# Epoch: 7/20...  Training Step: 27100...  Training loss: 1.1586...  0.0422 sec/batch
# Epoch: 7/20...  Training Step: 27150...  Training loss: 1.3986...  0.0415 sec/batch
# Epoch: 7/20...  Training Step: 27200...  Training loss: 1.2206...  0.0444 sec/batch
# Epoch: 7/20...  Training Step: 27250...  Training loss: 1.1789...  0.0446 sec/batch
# Epoch: 7/20...  Training Step: 27300...  Training loss: 1.1320...  0.0425 sec/batch
# Epoch: 7/20...  Training Step: 27350...  Training loss: 1.2262...  0.0412 sec/batch
# Epoch: 7/20...  Training Step: 27400...  Training loss: 1.1486...  0.0425 sec/batch
# Epoch: 7/20...  Training Step: 27450...  Training loss: 1.1760...  0.0423 sec/batch
# Epoch: 7/20...  Training Step: 27500...  Training loss: 1.4404...  0.0416 sec/batch
# Epoch: 7/20...  Training Step: 27550...  Training loss: 1.4162...  0.0452 sec/batch
# Epoch: 7/20...  Training Step: 27600...  Training loss: 1.4888...  0.0451 sec/batch
# Epoch: 7/20...  Training Step: 27650...  Training loss: 1.2758...  0.0445 sec/batch
# Epoch: 7/20...  Training Step: 27700...  Training loss: 1.2482...  0.0428 sec/batch
# Epoch: 7/20...  Training Step: 27750...  Training loss: 1.3294...  0.0443 sec/batch
# Epoch: 8/20...  Training Step: 27800...  Training loss: 1.3002...  0.0442 sec/batch
# Epoch: 8/20...  Training Step: 27850...  Training loss: 1.2830...  0.0422 sec/batch
# Epoch: 8/20...  Training Step: 27900...  Training loss: 1.2330...  0.0424 sec/batch
# Epoch: 8/20...  Training Step: 27950...  Training loss: 1.4015...  0.0416 sec/batch
# Epoch: 8/20...  Training Step: 28000...  Training loss: 1.2337...  0.0450 sec/batch
# Epoch: 8/20...  Training Step: 28050...  Training loss: 1.1307...  0.0441 sec/batch
# Epoch: 8/20...  Training Step: 28100...  Training loss: 1.3683...  0.0438 sec/batch
# Epoch: 8/20...  Training Step: 28150...  Training loss: 1.3360...  0.0422 sec/batch
# Epoch: 8/20...  Training Step: 28200...  Training loss: 1.2581...  0.0446 sec/batch
# Epoch: 8/20...  Training Step: 28250...  Training loss: 1.3941...  0.0443 sec/batch
# Epoch: 8/20...  Training Step: 28300...  Training loss: 1.3785...  0.0423 sec/batch
# Epoch: 8/20...  Training Step: 28350...  Training loss: 1.2826...  0.0446 sec/batch
# Epoch: 8/20...  Training Step: 28400...  Training loss: 1.2942...  0.0429 sec/batch
# Epoch: 8/20...  Training Step: 28450...  Training loss: 1.2212...  0.0422 sec/batch
# Epoch: 8/20...  Training Step: 28500...  Training loss: 1.3126...  0.0446 sec/batch
# Epoch: 8/20...  Training Step: 28550...  Training loss: 1.0921...  0.0442 sec/batch
# Epoch: 8/20...  Training Step: 28600...  Training loss: 1.1978...  0.0422 sec/batch
# Epoch: 8/20...  Training Step: 28650...  Training loss: 1.5072...  0.0450 sec/batch
# Epoch: 8/20...  Training Step: 28700...  Training loss: 1.3341...  0.0429 sec/batch
# Epoch: 8/20...  Training Step: 28750...  Training loss: 1.2512...  0.0428 sec/batch
# Epoch: 8/20...  Training Step: 28800...  Training loss: 1.3604...  0.0420 sec/batch
# Epoch: 8/20...  Training Step: 28850...  Training loss: 1.2030...  0.0425 sec/batch
# Epoch: 8/20...  Training Step: 28900...  Training loss: 1.2024...  0.0445 sec/batch
# Epoch: 8/20...  Training Step: 28950...  Training loss: 1.1751...  0.0422 sec/batch
# Epoch: 8/20...  Training Step: 29000...  Training loss: 1.2480...  0.0427 sec/batch
# Epoch: 8/20...  Training Step: 29050...  Training loss: 1.2719...  0.0427 sec/batch
# Epoch: 8/20...  Training Step: 29100...  Training loss: 1.2904...  0.0448 sec/batch
# Epoch: 8/20...  Training Step: 29150...  Training loss: 1.1419...  0.0447 sec/batch
# Epoch: 8/20...  Training Step: 29200...  Training loss: 1.2642...  0.0443 sec/batch
# Epoch: 8/20...  Training Step: 29250...  Training loss: 1.3291...  0.0415 sec/batch
# Epoch: 8/20...  Training Step: 29300...  Training loss: 1.1921...  0.0420 sec/batch
# Epoch: 8/20...  Training Step: 29350...  Training loss: 1.3576...  0.0443 sec/batch
# Epoch: 8/20...  Training Step: 29400...  Training loss: 1.3292...  0.0430 sec/batch
# Epoch: 8/20...  Training Step: 29450...  Training loss: 1.1193...  0.0430 sec/batch
# Epoch: 8/20...  Training Step: 29500...  Training loss: 1.1994...  0.0425 sec/batch
# Epoch: 8/20...  Training Step: 29550...  Training loss: 1.2279...  0.0426 sec/batch
# Epoch: 8/20...  Training Step: 29600...  Training loss: 1.1271...  0.0444 sec/batch
# Epoch: 8/20...  Training Step: 29650...  Training loss: 1.2278...  0.0421 sec/batch
# Epoch: 8/20...  Training Step: 29700...  Training loss: 1.1694...  0.0421 sec/batch
# Epoch: 8/20...  Training Step: 29750...  Training loss: 1.3296...  0.0416 sec/batch
# Epoch: 8/20...  Training Step: 29800...  Training loss: 1.2040...  0.0422 sec/batch
# Epoch: 8/20...  Training Step: 29850...  Training loss: 1.2181...  0.0420 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-6fbd3ad10191> in <module>()
#      31                                                  model.final_state,
#      32                                                  model.optimizer],
# ---> 33                                                  feed_dict=feed)
#      34             if (counter % print_every_n == 0):
#      35                 end = time.time()
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i29800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i20000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i20200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i20400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i20600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i20800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i21000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i21200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i21400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i21600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i21800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i22000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i22200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i22400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i22600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i22800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i23000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i23200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i23400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i23600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i23800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i24000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i24200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i24400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i24600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i24800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i25000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i25200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i25400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i25600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i25800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i26000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i26200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i26400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i26600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i26800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i27000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i27200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i27400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i27600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i27800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i28000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i28200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i28400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i28600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i28800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i29000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i29200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i29400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i29600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i29800_l128.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i29800_l128.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i29800_l128.ckpt
# Farly all this," said Dolly and she had been at her face as has the changed his sister," said
# Agafea Mihalovna as he said an official corriponed walkings oval suppose had," he said.
# "And I have never, the same, he had all," said Anna," said Alexey, stayed simply at a sorty-partical society of the little, he was a specially that he was not the sunse. And that heard out of the
# correct on those sort of
# love and he could heard had been saying how happy and will set it in him, a love, which they sub and forgiven over, and what are your, thun you have speaking and had a man to be the capsures. Stepan Arkadyevitch's
# sister. The portrait of his sisters turned, had happened, he would have become for a littoned hanged another corrading to his sisters of happiness as sit, who had seemed to her friend he knew that tears that she had been a comming," said Anna, he had natural as he was shame. It was had her as it was him a lawer. He shaves of
# the
# legs, she knew it was his wife and
# traced."
#
# "Ah, her eyes. Stepan
# Arkadyevitch seen and here and than it was already.
#
# "You do a minutes, should be apprecially," she said that his cross of his fach
# at the right of his
# forch that he was not all of her hand of
# his compant of sign and the chair that was that here the
# bell at her, had not
# for and
# all had become
# here he was so an acquaint that she knew is in all she, her fulles and
# hour that he had had to talk of
# the
# princess was so feel that this was ill that he had a lot of that
# women
# and tried to his called the fact and sorrow a friend of the supposed happies.""
# Levan that she's an appearly and her socy shaken his wife of heart of
# suddand that's a love of the reflies.
#
# Anna, his capital shortly of how some coaching
# one such
# salvatial.
#
# And that he said that he said, and her," said Anna, should not be something the same truth and himself to the love. And
# the priest, she had subject, and that he was now. He's not that the pills and her brandrained had a money and half-called her heart
# whether

# %%
checkpoint = 'checkpoints/i10200_l128.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i10200_l128.ckpt
# Fark anything to the
# most to speak. Their side.
# That holying the cries well, he was so short and difficulty of her several smile to their maid. And that they had been
# any not that she had felt and that the moment the starriathe wheater he smiles other steps, to the miseroom, and she was tills
# to her hostes, she did not hangs he sat halling that the partent to her husband.
#
# "The people of the points, and there was a count tears, and her seems of
# the mother hand.
#
# "It is it to the
# marshes. And,
# as answer in their mistefuh
# took, he wents
# and short he hads had stay and as to say that some one tears of ansudians of the stepes of with her between her. So in
# he had seen, take the mattand of she was assection
# or thoughts, what the peal a little moments on and and supposing the sudden to the stranger, and along into their heart."
#
# "What she was a lotter of
# succeet, their course where she was last in herself, what they had brought her a princess, and he carried
# his husband's she came
# the parter, and

# %%
checkpoint = 'checkpoints/i12800_l128.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i12800_l128.ckpt
# Fards and staying over. Allow the same and black, the traces, but as though he had to hard hundred to him and
# they had been should never setrows was all the seen. I have beats and his brothers and
# shade. Hatred and as a smotest and hates when she had settling him to her shoulders alone. His acquiver, and his stream."
#
# "Yes, but the condition and help an idea of his strivese they shall be taken the statement tear and the president. He was to blounked her, and the carriage of the peasant.
#
# "Yes. "We have and he knows to her. But when there was a tears, and waited to the marm, and the seeded the soft that hear in
# his acquaintant winging off
# all. They could never talk of his son.
#
# "I see that with them. He should not be shall have
# time. There, and his and taken in their beauty. This they were a seen, that the chad," that they're took on
# sick all, had answered all the clungers.
#
# They didn't know what they had broke a misucks, they had. They were a memorys and horses were all. That's necessity o

# %%
checkpoint = 'checkpoints/i16200_l128.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i16200_l128.ckpt
# Farn, an about the convartion. Here as a playing or time was stricking his
# silence,
# and any
# said his heart to say
# he had nothing to thinks, to bring me. The second about, was the carriage, that he had still an income to her begave me, I want the creaking at it agay to think of holds. He mean he
# saw that the churces to see anything of her."
#
# "Only what
# do you know, and
# had not save
# me!" answered Stepan
# Arkadyevitch, and
# the same incread, as abus table will be true about them, and the presation. Allow me at here. But what made up the more from her brought to them was a princess to be supposed in the clover, and
# said to
# him and was a completely so as into
# man, with success or all that was not to her hands whom the presence," answered Alexey Alexandrovitch and he said.
#
# Time. "You supposed or all so much, but what
# me," she said, and the lip.
#
# The sunseorery
# without all the many.
#
# The little waiting and winking. He were so playing the peasants. Their health, will be nothing of than talk of the

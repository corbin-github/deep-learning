# %% [markdown]
# # Transfer Learning
#
# Most of the time you won't want to train a whole convolutional network yourself. Modern ConvNets training on huge datasets like ImageNet take weeks on multiple GPUs. Instead, most people use a pretrained network either as a fixed feature extractor, or as an initial network to fine tune. In this notebook, you'll be using [VGGNet](https://arxiv.org/pdf/1409.1556.pdf) trained on the [ImageNet dataset](http://www.image-net.org/) as a feature extractor. Below is a diagram of the VGGNet architecture.
#
# <img src="assets/cnnarchitecture.jpg" width=700px>
#
# VGGNet is great because it's simple and has great performance, coming in second in the ImageNet competition. The idea here is that we keep all the convolutional layers, but replace the final fully connected layers with our own classifier. This way we can use VGGNet as a feature extractor for our images then easily train a simple classifier on top of that. What we'll do is take the first fully connected layer with 4096 units, including thresholding with ReLUs. We can use those values as a code for each image, then build a classifier on top of those codes.
#
# You can read more about transfer learning from [the CS231n course notes](http://cs231n.github.io/transfer-learning/#tf).
#
# ## Pretrained VGGNet
#
# We'll be using a pretrained network from https://github.com/machrisaa/tensorflow-vgg. This code is already included in 'tensorflow_vgg' directory, sdo you don't have to clone it.
#
# This is a really nice implementation of VGGNet, quite easy to work with. The network has already been trained and the parameters are available from this link. **You'll need to clone the repo into the folder containing this notebook.** Then download the parameter file using the next cell.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm

vgg_dir = 'tensorflow_vgg/'
# Make sure vgg exists
if not isdir(vgg_dir):
    raise Exception("VGG directory doesn't exist!")

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(vgg_dir + "vgg16.npy"):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='VGG16 Parameters') as pbar:
        urlretrieve(
            'https://s3.amazonaws.com/content.udacity-data.com/nd101/vgg16.npy',
            vgg_dir + 'vgg16.npy',
            pbar.hook)
else:
    print("Parameter file already exists!")
# Out:
# VGG16 Parameters: 553MB [00:09, 57.6MB/s]

# %% [markdown]
# ## Flower power
#
# Here we'll be using VGGNet to classify images of flowers. To get the flower dataset, run the cell below. This dataset comes from the [TensorFlow inception tutorial](https://www.tensorflow.org/tutorials/image_retraining).

# %%
import tarfile

dataset_folder_path = 'flower_photos'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('flower_photos.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='Flowers Dataset') as pbar:
        urlretrieve(
            'http://download.tensorflow.org/example_images/flower_photos.tgz',
            'flower_photos.tar.gz',
            pbar.hook)

if not isdir(dataset_folder_path):
    with tarfile.open('flower_photos.tar.gz') as tar:
        tar.extractall()
        tar.close()
# Out:
# Flowers Dataset: 229MB [00:04, 54.2MB/s]

# %% [markdown]
# ## ConvNet Codes
#
# Below, we'll run through all the images in our dataset and get codes for each of them. That is, we'll run the images through the VGGNet convolutional layers and record the values of the first fully connected layer. We can then write these to a file for later when we build our own classifier.
#
# Here we're using the `vgg16` module from `tensorflow_vgg`. The network takes images of size $224 \times 224 \times 3$ as input. Then it has 5 sets of convolutional layers. The network implemented here has this structure (copied from [the source code](https://github.com/machrisaa/tensorflow-vgg/blob/master/vgg16.py)):
#
# ```
# self.conv1_1 = self.conv_layer(bgr, "conv1_1")
# self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
# self.pool1 = self.max_pool(self.conv1_2, 'pool1')
#
# self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
# self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
# self.pool2 = self.max_pool(self.conv2_2, 'pool2')
#
# self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
# self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
# self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
# self.pool3 = self.max_pool(self.conv3_3, 'pool3')
#
# self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
# self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
# self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
# self.pool4 = self.max_pool(self.conv4_3, 'pool4')
#
# self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
# self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
# self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
# self.pool5 = self.max_pool(self.conv5_3, 'pool5')
#
# self.fc6 = self.fc_layer(self.pool5, "fc6")
# self.relu6 = tf.nn.relu(self.fc6)
# ```
#
# So what we want are the values of the first fully connected layer, after being ReLUd (`self.relu6`). To build the network, we use
#
# ```
# with tf.Session() as sess:
#     vgg = vgg16.Vgg16()
#     input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
#     with tf.name_scope("content_vgg"):
#         vgg.build(input_)
# ```
#
# This creates the `vgg` object, then builds the graph with `vgg.build(input_)`. Then to get the values from the layer,
#
# ```
# feed_dict = {input_: images}
# codes = sess.run(vgg.relu6, feed_dict=feed_dict)
# ```

# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

# %%
data_dir = 'flower_photos/'
contents = os.listdir(data_dir)
classes = [each for each in contents if os.path.isdir(data_dir + each)]

# %% [markdown]
# Below I'm running images through the VGG network in batches.
#
# > **Exercise:** Below, build the VGG network. Also get the codes from the first fully connected layer (make sure you get the ReLUd values).

# %%
# Set the batch size higher if you can fit in in your GPU memory
batch_size = 10
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:
    
    # TODO: Build the vgg network here
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            print (class_path + file)
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                
                # Image batch to pass to VGG network
                images = np.concatenate(batch)
                
                # TODO: Get the values from the relu6 layer of the VGG network
                feed_dict = {input_: images}
                codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# /home/ubuntu/corbin_dl/deep-learning/transfer-learning/tensorflow_vgg/vgg16.npy
# npy file loaded
# build model started
# build model finished: 0s
# Starting roses images
# flower_photos/roses17077876795_6dd1b03f54_m.jpg
# flower_photos/roses19566556880_476c66c5ee_n.jpg
# flower_photos/roses14810868100_87eb739f26_m.jpg
# flower_photos/roses15999816377_4b95e0b538_n.jpg
# flower_photos/roses2053476785_c162a3e358.jpg
# flower_photos/roses6690926183_afedba9f15_n.jpg
# flower_photos/roses2627513944_b1361e60ec_m.jpg
# flower_photos/roses18389368680_91c24a2087_z.jpg
# flower_photos/roses8096324039_4db2555490.jpg
# flower_photos/roses15104537437_f6730b38c3_n.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-f3f266efeb18> in <module>()
#      35                 # TODO: Get the values from the relu6 layer of the VGG network
#      36                 feed_dict = {input_: images}
# ---> 37                 codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
#      38
#      39                 # Here I'm building an array of the codes
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# write codes to file
with open('codes', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %% [markdown]
# ## Building the Classifier
#
# Now that we have codes for all the images, we can build a simple classifier on top of them. The codes behave just like normal input into a simple neural network. Below I'm going to have you do most of the work.

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
len(labels)
# Out:
# 3670

# %%
codes.shape
# Out:
# (3670, 4096)

# %% [markdown]
# ### Data prep
#
# As usual, now we need to one-hot encode our labels and create validation/test sets. First up, creating our labels!
#
# > **Exercise:** From scikit-learn, use [LabelBinarizer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html) to create one-hot encoded vectors from the labels.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(labels)
lb.classes_

# %%
labels_vecs = lb.transform(labels) # Your one-hot encoded labels array here

# %% [markdown]
# Now you'll want to create your training, validation, and test sets. An important thing to note here is that our labels and data aren't randomized yet. We'll want to shuffle our data so the validation and test sets contain data from all classes. Otherwise, you could end up with testing sets that are all one class. Typically, you'll also want to make sure that each smaller set has the same the distribution of classes as it is for the whole data set. The easiest way to accomplish both these goals is to use [`StratifiedShuffleSplit`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) from scikit-learn.
#
# You can create the splitter like so:
# ```
# ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
# ```
# Then split the data with
# ```
# splitter = ss.split(x, y)
# ```
#
# `ss.split` returns a generator of indices. You can pass the indices into the arrays to get the split sets. The fact that it's a generator means you either need to iterate over it, or use `next(splitter)` to get the indices. Be sure to read the [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) and the [user guide](http://scikit-learn.org/stable/modules/cross_validation.html#random-permutations-cross-validation-a-k-a-shuffle-split).
#
# > **Exercise:** Use StratifiedShuffleSplit to split the codes and labels into training, validation, and test sets.

# %%
from sklearn.model_selection import StratifiedShuffleSplit
ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
ss.get_n_splits(codes, labels_vecs)
print(ss)
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=0, test_size=0.2,
#             train_size=None)

# %%
splitter = ss.split(codes, labels_vecs)

# %%
train_index, test_index = next(splitter)
print("TRAIN:", str(len(train_index)), "TEST:", str(len(test_index)))
train_x, train_y = codes[train_index], labels_vecs[train_index]
codes2, labels_vecs2 = codes[test_index], labels_vecs[test_index]
# Out:
# TRAIN: 2936 TEST: 734

# %%
ss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=0)
splitter2 = ss2.split(codes2, labels_vecs2)

# %%
val_index, test_index = next(splitter2)
print("VAL:", str(len(val_index)), "TEST:", str(len(test_index)))
val_x, val_y = codes[val_index], labels_vecs[val_index]
test_x, test_y = codes[test_index], labels_vecs[test_index]
# Out:
# VAL: 367 TEST: 367

# %%
print("Train shapes (x, y):", train_x.shape, train_y.shape)
print("Validation shapes (x, y):", val_x.shape, val_y.shape)
print("Test shapes (x, y):", test_x.shape, test_y.shape)
# Out:
# Train shapes (x, y): (2936, 4096) (2936, 5)
# Validation shapes (x, y): (367, 4096) (367, 5)
# Test shapes (x, y): (367, 4096) (367, 5)

# %% [markdown]
# If you did it right, you should see these sizes for the training sets:
#
# ```
# Train shapes (x, y): (2936, 4096) (2936, 5)
# Validation shapes (x, y): (367, 4096) (367, 5)
# Test shapes (x, y): (367, 4096) (367, 5)
# ```

# %% [markdown]
# ### Classifier layers
#
# Once you have the convolutional codes, you just need to build a classfier from some fully connected layers. You use the codes as the inputs and the image labels as targets. Otherwise the classifier is a typical neural network.
#
# > **Exercise:** With the codes and labels loaded, build the classifier. Consider the codes as your inputs, each of them are 4096D vectors. You'll want to use a hidden layer and an output layer as your classifier. Remember that the output layer needs to have one unit for each class and a softmax activation function. Use the cross entropy to calculate the cost.

# %%
inputs_ = tf.placeholder(tf.float32, shape=[None, codes.shape[1]], name = "inputs")
labels_ = tf.placeholder(tf.float32, shape=[None, labels_vecs.shape[1]], name = "labels")

# TODO: Classifier layers and operations
hidden = tf.contrib.layers.fully_connected(inputs_, 2000) # relu is default here!
#tf.layers.dense(inputs_, 200, activation = tf.nn.relu)

logits = tf.contrib.layers.fully_connected(hidden, labels_vecs.shape[1], activation_fn = None) 
# tf.layers.dense(hidden, labels_vecs.shape[1], activation = None) # output layer logits

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels = labels_, logits = logits) # cross entropy loss

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)

optimizer = tf.train.AdamOptimizer(learning_rate = 0.001).minimize(cost) # training optimizer

# Operations for validation/test accuracy
predicted = tf.nn.softmax(logits, name = "outputs")
correct_pred = tf.equal(tf.argmax(predicted, 1), tf.argmax(labels_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ### Batches!
#
# Here is just a simple way to do batches. I've written it so that it includes all the data. Sometimes you'll throw out some data at the end to make sure you have full batches. Here I just extend the last batch to include the remaining data.

# %%
def get_batches(x, y, n_batches=10):
    """ Return a generator that yields batches from arrays x and y. """
    batch_size = len(x)//n_batches
    
    for ii in range(0, n_batches*batch_size, batch_size):
        # If we're not on the last batch, grab data with size batch_size
        if ii != (n_batches-1)*batch_size:
            X, Y = x[ii: ii+batch_size], y[ii: ii+batch_size] 
        # On the last batch, grab the rest of the data
        else:
            X, Y = x[ii:], y[ii:]
        # I love generators
        yield X, Y

# %% [markdown]
# ### Training
#
# Here, we'll train the network.
#
# > **Exercise:** So far we've been providing the training code for you. Here, I'm going to give you a bit more of a challenge and have you write the code to train the network. Of course, you'll be able to see my solution if you need help. Use the `get_batches` function I wrote before to get your batches like `for x, y in get_batches(train_x, train_y)`. Or write your own!

# %%
saver = tf.train.Saver()
epochs = 20
iteration = 0

with tf.Session() as sess:
    
    # TODO: Your training code here
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for x, y in get_batches(train_x, train_y):
            batch_cost, _ = sess.run([cost, optimizer], feed_dict={inputs_: x, labels_: y})

            print("Epoch: {}/{}...".format(e+1, epochs),
                  "Iteration: {}".format(iteration),
                  "Training loss: {:.5f}".format(batch_cost))
            iteration += 1
            
            if iteration % 5 == 0:
                feed = {inputs_: val_x, labels_: val_y}
                val_acc = sess.run(accuracy, feed_dict=feed)
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Validation Acc: {:.4f}".format(val_acc))
       
    saver.save(sess, "checkpoints/flowers.ckpt")
# Out:
# Epoch: 1/20... Iteration: 0 Training loss: 2.14504
# Epoch: 1/20... Iteration: 1 Training loss: 11.62208
# Epoch: 1/20... Iteration: 2 Training loss: 9.60940
# Epoch: 1/20... Iteration: 3 Training loss: 9.17194
# Epoch: 1/20... Iteration: 4 Training loss: 6.23140
# Epoch: 0/20 Iteration: 5 Validation Acc: 0.6921
# Epoch: 1/20... Iteration: 5 Training loss: 3.15344
# Epoch: 1/20... Iteration: 6 Training loss: 1.36592
# Epoch: 1/20... Iteration: 7 Training loss: 2.06685
# Epoch: 1/20... Iteration: 8 Training loss: 2.38893
# Epoch: 1/20... Iteration: 9 Training loss: 2.47862
# Epoch: 0/20 Iteration: 10 Validation Acc: 0.6975
# Epoch: 2/20... Iteration: 10 Training loss: 1.79931
# Epoch: 2/20... Iteration: 11 Training loss: 1.49556
# Epoch: 2/20... Iteration: 12 Training loss: 0.74158
# Epoch: 2/20... Iteration: 13 Training loss: 0.70231
# Epoch: 2/20... Iteration: 14 Training loss: 0.61694
# Epoch: 1/20 Iteration: 15 Validation Acc: 0.6785
# Epoch: 2/20... Iteration: 15 Training loss: 0.75867
# Epoch: 2/20... Iteration: 16 Training loss: 0.72567
# Epoch: 2/20... Iteration: 17 Training loss: 0.65270
# Epoch: 2/20... Iteration: 18 Training loss: 0.63244
# Epoch: 2/20... Iteration: 19 Training loss: 0.60225
# Epoch: 1/20 Iteration: 20 Validation Acc: 0.9537
# Epoch: 3/20... Iteration: 20 Training loss: 0.54995
# Epoch: 3/20... Iteration: 21 Training loss: 0.42927
# Epoch: 3/20... Iteration: 22 Training loss: 0.36303
# Epoch: 3/20... Iteration: 23 Training loss: 0.34567
# Epoch: 3/20... Iteration: 24 Training loss: 0.30727
# Epoch: 2/20 Iteration: 25 Validation Acc: 0.8965
# Epoch: 3/20... Iteration: 25 Training loss: 0.30862
# Epoch: 3/20... Iteration: 26 Training loss: 0.28139
# Epoch: 3/20... Iteration: 27 Training loss: 0.27163
# Epoch: 3/20... Iteration: 28 Training loss: 0.25219
# Epoch: 3/20... Iteration: 29 Training loss: 0.27611
# Epoch: 2/20 Iteration: 30 Validation Acc: 0.9210
# Epoch: 4/20... Iteration: 30 Training loss: 0.19169
# Epoch: 4/20... Iteration: 31 Training loss: 0.19212
# Epoch: 4/20... Iteration: 32 Training loss: 0.14517
# Epoch: 4/20... Iteration: 33 Training loss: 0.12467
# Epoch: 4/20... Iteration: 34 Training loss: 0.14540
# Epoch: 3/20 Iteration: 35 Validation Acc: 0.8501
# Epoch: 4/20... Iteration: 35 Training loss: 0.14197
# Epoch: 4/20... Iteration: 36 Training loss: 0.14406
# Epoch: 4/20... Iteration: 37 Training loss: 0.17366
# Epoch: 4/20... Iteration: 38 Training loss: 0.10067
# Epoch: 4/20... Iteration: 39 Training loss: 0.10143
# Epoch: 3/20 Iteration: 40 Validation Acc: 0.9700
# Epoch: 5/20... Iteration: 40 Training loss: 0.08983
# Epoch: 5/20... Iteration: 41 Training loss: 0.10719
# Epoch: 5/20... Iteration: 42 Training loss: 0.09493
# Epoch: 5/20... Iteration: 43 Training loss: 0.08279
# Epoch: 5/20... Iteration: 44 Training loss: 0.06489
# Epoch: 4/20 Iteration: 45 Validation Acc: 0.9510
# Epoch: 5/20... Iteration: 45 Training loss: 0.06461
# Epoch: 5/20... Iteration: 46 Training loss: 0.08531
# Epoch: 5/20... Iteration: 47 Training loss: 0.10235
# Epoch: 5/20... Iteration: 48 Training loss: 0.07489
# Epoch: 5/20... Iteration: 49 Training loss: 0.07538
# Epoch: 4/20 Iteration: 50 Validation Acc: 0.9728
# Epoch: 6/20... Iteration: 50 Training loss: 0.05428
# Epoch: 6/20... Iteration: 51 Training loss: 0.06537
# Epoch: 6/20... Iteration: 52 Training loss: 0.05037
# Epoch: 6/20... Iteration: 53 Training loss: 0.05010
# Epoch: 6/20... Iteration: 54 Training loss: 0.04943
# Epoch: 5/20 Iteration: 55 Validation Acc: 0.9755
# Epoch: 6/20... Iteration: 55 Training loss: 0.04701
# Epoch: 6/20... Iteration: 56 Training loss: 0.04212
# Epoch: 6/20... Iteration: 57 Training loss: 0.06170
# Epoch: 6/20... Iteration: 58 Training loss: 0.03388
# Epoch: 6/20... Iteration: 59 Training loss: 0.06380
# Epoch: 5/20 Iteration: 60 Validation Acc: 0.9482
# Epoch: 7/20... Iteration: 60 Training loss: 0.03812
# Epoch: 7/20... Iteration: 61 Training loss: 0.04841
# Epoch: 7/20... Iteration: 62 Training loss: 0.03329
# Epoch: 7/20... Iteration: 63 Training loss: 0.02980
# Epoch: 7/20... Iteration: 64 Training loss: 0.03021
# Epoch: 6/20 Iteration: 65 Validation Acc: 0.9782
# Epoch: 7/20... Iteration: 65 Training loss: 0.03284
# Epoch: 7/20... Iteration: 66 Training loss: 0.03212
# Epoch: 7/20... Iteration: 67 Training loss: 0.03981
# Epoch: 7/20... Iteration: 68 Training loss: 0.02920
# Epoch: 7/20... Iteration: 69 Training loss: 0.03847
# Epoch: 6/20 Iteration: 70 Validation Acc: 0.9700
# Epoch: 8/20... Iteration: 70 Training loss: 0.02389
# Epoch: 8/20... Iteration: 71 Training loss: 0.03480
# Epoch: 8/20... Iteration: 72 Training loss: 0.02610
# Epoch: 8/20... Iteration: 73 Training loss: 0.02370
# Epoch: 8/20... Iteration: 74 Training loss: 0.02078
# Epoch: 7/20 Iteration: 75 Validation Acc: 0.9673
# Epoch: 8/20... Iteration: 75 Training loss: 0.02218
# Epoch: 8/20... Iteration: 76 Training loss: 0.02600
# Epoch: 8/20... Iteration: 77 Training loss: 0.02773
# Epoch: 8/20... Iteration: 78 Training loss: 0.01743
# Epoch: 8/20... Iteration: 79 Training loss: 0.03063
# Epoch: 7/20 Iteration: 80 Validation Acc: 0.9809
# Epoch: 9/20... Iteration: 80 Training loss: 0.01641
# Epoch: 9/20... Iteration: 81 Training loss: 0.02884
# Epoch: 9/20... Iteration: 82 Training loss: 0.01531
# Epoch: 9/20... Iteration: 83 Training loss: 0.01917
# Epoch: 9/20... Iteration: 84 Training loss: 0.01592
# Epoch: 8/20 Iteration: 85 Validation Acc: 0.9728
# Epoch: 9/20... Iteration: 85 Training loss: 0.01758
# Epoch: 9/20... Iteration: 86 Training loss: 0.02026
# Epoch: 9/20... Iteration: 87 Training loss: 0.02303
# Epoch: 9/20... Iteration: 88 Training loss: 0.01423
# Epoch: 9/20... Iteration: 89 Training loss: 0.02359
# Epoch: 8/20 Iteration: 90 Validation Acc: 0.9728
# Epoch: 10/20... Iteration: 90 Training loss: 0.01123
# Epoch: 10/20... Iteration: 91 Training loss: 0.01998
# Epoch: 10/20... Iteration: 92 Training loss: 0.01162
# Epoch: 10/20... Iteration: 93 Training loss: 0.01497
# Epoch: 10/20... Iteration: 94 Training loss: 0.01252
# Epoch: 9/20 Iteration: 95 Validation Acc: 0.9755
# Epoch: 10/20... Iteration: 95 Training loss: 0.01503
# Epoch: 10/20... Iteration: 96 Training loss: 0.01509
# Epoch: 10/20... Iteration: 97 Training loss: 0.01722
# Epoch: 10/20... Iteration: 98 Training loss: 0.01093
# Epoch: 10/20... Iteration: 99 Training loss: 0.01760
# Epoch: 9/20 Iteration: 100 Validation Acc: 0.9700
# Epoch: 11/20... Iteration: 100 Training loss: 0.00920
# Epoch: 11/20... Iteration: 101 Training loss: 0.01418
# Epoch: 11/20... Iteration: 102 Training loss: 0.00964
# Epoch: 11/20... Iteration: 103 Training loss: 0.01198
# Epoch: 11/20... Iteration: 104 Training loss: 0.00919
# Epoch: 10/20 Iteration: 105 Validation Acc: 0.9700
# Epoch: 11/20... Iteration: 105 Training loss: 0.01202
# Epoch: 11/20... Iteration: 106 Training loss: 0.01214
# Epoch: 11/20... Iteration: 107 Training loss: 0.01393
# Epoch: 11/20... Iteration: 108 Training loss: 0.00824
# Epoch: 11/20... Iteration: 109 Training loss: 0.01319
# Epoch: 10/20 Iteration: 110 Validation Acc: 0.9728
# Epoch: 12/20... Iteration: 110 Training loss: 0.00749
# Epoch: 12/20... Iteration: 111 Training loss: 0.01120
# Epoch: 12/20... Iteration: 112 Training loss: 0.00767
# Epoch: 12/20... Iteration: 113 Training loss: 0.00998
# Epoch: 12/20... Iteration: 114 Training loss: 0.00757
# Epoch: 11/20 Iteration: 115 Validation Acc: 0.9700
# Epoch: 12/20... Iteration: 115 Training loss: 0.00994
# Epoch: 12/20... Iteration: 116 Training loss: 0.01009
# Epoch: 12/20... Iteration: 117 Training loss: 0.01184
# Epoch: 12/20... Iteration: 118 Training loss: 0.00675
# Epoch: 12/20... Iteration: 119 Training loss: 0.01034
# Epoch: 11/20 Iteration: 120 Validation Acc: 0.9700
# Epoch: 13/20... Iteration: 120 Training loss: 0.00625
# Epoch: 13/20... Iteration: 121 Training loss: 0.00908
# Epoch: 13/20... Iteration: 122 Training loss: 0.00643
# Epoch: 13/20... Iteration: 123 Training loss: 0.00848
# Epoch: 13/20... Iteration: 124 Training loss: 0.00617
# Epoch: 12/20 Iteration: 125 Validation Acc: 0.9700
# Epoch: 13/20... Iteration: 125 Training loss: 0.00833
# Epoch: 13/20... Iteration: 126 Training loss: 0.00821
# Epoch: 13/20... Iteration: 127 Training loss: 0.00981
# Epoch: 13/20... Iteration: 128 Training loss: 0.00547
# Epoch: 13/20... Iteration: 129 Training loss: 0.00780
# Epoch: 12/20 Iteration: 130 Validation Acc: 0.9700
# Epoch: 14/20... Iteration: 130 Training loss: 0.00545
# Epoch: 14/20... Iteration: 131 Training loss: 0.00722
# Epoch: 14/20... Iteration: 132 Training loss: 0.00550
# Epoch: 14/20... Iteration: 133 Training loss: 0.00701
# Epoch: 14/20... Iteration: 134 Training loss: 0.00504
# Epoch: 13/20 Iteration: 135 Validation Acc: 0.9700
# Epoch: 14/20... Iteration: 135 Training loss: 0.00668
# Epoch: 14/20... Iteration: 136 Training loss: 0.00712
# Epoch: 14/20... Iteration: 137 Training loss: 0.00849
# Epoch: 14/20... Iteration: 138 Training loss: 0.00450
# Epoch: 14/20... Iteration: 139 Training loss: 0.00625
# Epoch: 13/20 Iteration: 140 Validation Acc: 0.9700
# Epoch: 15/20... Iteration: 140 Training loss: 0.00473
# Epoch: 15/20... Iteration: 141 Training loss: 0.00610
# Epoch: 15/20... Iteration: 142 Training loss: 0.00460
# Epoch: 15/20... Iteration: 143 Training loss: 0.00607
# Epoch: 15/20... Iteration: 144 Training loss: 0.00439
# Epoch: 14/20 Iteration: 145 Validation Acc: 0.9700
# Epoch: 15/20... Iteration: 145 Training loss: 0.00574
# Epoch: 15/20... Iteration: 146 Training loss: 0.00598
# Epoch: 15/20... Iteration: 147 Training loss: 0.00728
# Epoch: 15/20... Iteration: 148 Training loss: 0.00378
# Epoch: 15/20... Iteration: 149 Training loss: 0.00528
# Epoch: 14/20 Iteration: 150 Validation Acc: 0.9700
# Epoch: 16/20... Iteration: 150 Training loss: 0.00408
# Epoch: 16/20... Iteration: 151 Training loss: 0.00512
# Epoch: 16/20... Iteration: 152 Training loss: 0.00402
# Epoch: 16/20... Iteration: 153 Training loss: 0.00518
# Epoch: 16/20... Iteration: 154 Training loss: 0.00373
# Epoch: 15/20 Iteration: 155 Validation Acc: 0.9700
# Epoch: 16/20... Iteration: 155 Training loss: 0.00486
# Epoch: 16/20... Iteration: 156 Training loss: 0.00522
# Epoch: 16/20... Iteration: 157 Training loss: 0.00637
# Epoch: 16/20... Iteration: 158 Training loss: 0.00328
# Epoch: 16/20... Iteration: 159 Training loss: 0.00453
# Epoch: 15/20 Iteration: 160 Validation Acc: 0.9700
# Epoch: 17/20... Iteration: 160 Training loss: 0.00354
# Epoch: 17/20... Iteration: 161 Training loss: 0.00448
# Epoch: 17/20... Iteration: 162 Training loss: 0.00351
# Epoch: 17/20... Iteration: 163 Training loss: 0.00449
# Epoch: 17/20... Iteration: 164 Training loss: 0.00326
# Epoch: 16/20 Iteration: 165 Validation Acc: 0.9700
# Epoch: 17/20... Iteration: 165 Training loss: 0.00415
# Epoch: 17/20... Iteration: 166 Training loss: 0.00452
# Epoch: 17/20... Iteration: 167 Training loss: 0.00563
# Epoch: 17/20... Iteration: 168 Training loss: 0.00286
# Epoch: 17/20... Iteration: 169 Training loss: 0.00393
# Epoch: 16/20 Iteration: 170 Validation Acc: 0.9700
# Epoch: 18/20... Iteration: 170 Training loss: 0.00317
# Epoch: 18/20... Iteration: 171 Training loss: 0.00385
# Epoch: 18/20... Iteration: 172 Training loss: 0.00304
# Epoch: 18/20... Iteration: 173 Training loss: 0.00393
# Epoch: 18/20... Iteration: 174 Training loss: 0.00290
# Epoch: 17/20 Iteration: 175 Validation Acc: 0.9700
# Epoch: 18/20... Iteration: 175 Training loss: 0.00363
# Epoch: 18/20... Iteration: 176 Training loss: 0.00395
# Epoch: 18/20... Iteration: 177 Training loss: 0.00492
# Epoch: 18/20... Iteration: 178 Training loss: 0.00253
# Epoch: 18/20... Iteration: 179 Training loss: 0.00347
# Epoch: 17/20 Iteration: 180 Validation Acc: 0.9700
# Epoch: 19/20... Iteration: 180 Training loss: 0.00280
# Epoch: 19/20... Iteration: 181 Training loss: 0.00338
# Epoch: 19/20... Iteration: 182 Training loss: 0.00270
# Epoch: 19/20... Iteration: 183 Training loss: 0.00338
# Epoch: 19/20... Iteration: 184 Training loss: 0.00257
# Epoch: 18/20 Iteration: 185 Validation Acc: 0.9700
# Epoch: 19/20... Iteration: 185 Training loss: 0.00319
# Epoch: 19/20... Iteration: 186 Training loss: 0.00349
# Epoch: 19/20... Iteration: 187 Training loss: 0.00437
# Epoch: 19/20... Iteration: 188 Training loss: 0.00226
# Epoch: 19/20... Iteration: 189 Training loss: 0.00306
# Epoch: 18/20 Iteration: 190 Validation Acc: 0.9700
# Epoch: 20/20... Iteration: 190 Training loss: 0.00251
# Epoch: 20/20... Iteration: 191 Training loss: 0.00304
# Epoch: 20/20... Iteration: 192 Training loss: 0.00239
# Epoch: 20/20... Iteration: 193 Training loss: 0.00298
# Epoch: 20/20... Iteration: 194 Training loss: 0.00227
# Epoch: 19/20 Iteration: 195 Validation Acc: 0.9700
# Epoch: 20/20... Iteration: 195 Training loss: 0.00281
# Epoch: 20/20... Iteration: 196 Training loss: 0.00311
# Epoch: 20/20... Iteration: 197 Training loss: 0.00391
# Epoch: 20/20... Iteration: 198 Training loss: 0.00201
# Epoch: 20/20... Iteration: 199 Training loss: 0.00271
# Epoch: 19/20 Iteration: 200 Validation Acc: 0.9700

# %% [markdown]
# ### Testing
#
# Below you see the test accuracy. You can also see the predictions returned for images.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: test_x,
            labels_: test_y}
    test_acc = sess.run(accuracy, feed_dict=feed)
    print("Test accuracy: {:.4f}".format(test_acc))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/flowers.ckpt
# Test accuracy: 0.9864

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from scipy.ndimage import imread

# %% [markdown]
# Below, feel free to choose images and see how the trained classifier predicts the flowers in them.

# %%
test_img_path = 'flower_photos/roses/14810868100_87eb739f26_m.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)

# %%
# Run this cell if you don't have a vgg graph built
if 'vgg' in globals():
    print('"vgg" object already exists.  Will not create again.')
else:
    #create vgg
    with tf.Session() as sess:
        input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
        vgg = vgg16.Vgg16()
        vgg.build(input_)
# Out:
# "vgg" object already exists.  Will not create again.

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/flowers.ckpt

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(5), prediction)
_ = plt.yticks(np.arange(5), lb.classes_)
